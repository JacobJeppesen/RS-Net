# %%
import sys
import subprocess
import os
import datetime
import pandas as pd
import seaborn as sns
import gc
#from keras import backend as K
from PIL import Image
Image.MAX_IMAGE_PIXELS = 1000000000   
from matplotlib import pyplot as plt
'''
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
                                    # (nothing gets printed in Jupyter, only if you run it standalone)
sess = tf.Session(config=config)
set_session(sess)  # set this TensorFlow session as the default session for Keras
'''
sys.path.insert(0, '../')
# %load_ext autoreload
# %autoreload 2
from src.models.params import get_params
#from src.models.model_utils import evaluate_test_set, write_csv_files
#from src.models.Unet import Unet
#from src.visualization.make_image_files import visualize_test_data, visualize_landsat8_tile
#from src.visualization.visualization_utils import get_predicted_thumbnails 
#from src.utils import get_model_name

#%env CUDA_DEVICE_ORDER=PCI_BUS_ID
#%env CUDA_VISIBLE_DEVICES=0
# Out:
# /home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Define and run the training loops

# %%
activation_functions = ['relu', 'swish']
#loss_functions = ['binary_crossentropy', 'jaccard_coef_loss']
L2reg = [0, 1e-2]
#optimizers = ['Adam', 'Nadam']
dropout_vals = [0, 0.5]
epochs = 2
num_gpus = 2

# Train the models
for activation_func in activation_functions:
    for l2 in L2reg:
        #for optimizer in optimizers:
        for dropout in dropout_vals:
            params = get_params('U-net', 'Landsat8')
            params.modelID = datetime.datetime.now().strftime("%y%m%d%H%M%S")
            params.L2reg = l2
            params.optimizer = 'Adam'
            params.activation_func = activation_func
            params.dropout = dropout
            params.epochs = epochs
            params.brightness_augmentation = False
            params.batch_size = 16
            params.learning_rate = 1e-2
            
            cmd = "/home/jhj/phd/GitProjects/SentinelSemanticSegmentation/SentinelSemanticSegmentation.py" + \
                  " --train" + \
                  " --params=L2reg=" + str(l2) + \
                  " --params=dropout=" + str(dropout) + \
                  " --params=activation_func=" + activation_func

            # !/home/jhj/anaconda3/envs/CloudDetection/bin/python {cmd}
            
            # Try inserting this in a separate python script, and then run that script from here:
            # https://stackoverflow.com/questions/28126809/ipython-notebook-output-from-child-process
            # *Use subprocess.check_output
            
            
            
            
            
            
            #os.system("/home/jhj/anaconda3/envs/CloudDetection/bin/python /home/jhj/phd/GitProjects/SentinelSemanticSegmentation/SentinelSemanticSegmentation.py --train")
            #subprocess.call('/home/jhj/anaconda3/envs/CloudDetection/bin/python /home/jhj/phd/GitProjects/SentinelSemanticSegmentation/SentinelSemanticSegmentation.py --train', shell=True)
            # print('Done')
# Out:
# /home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 2018-04-05 19:23:48.057861: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-04-05 19:23:48.247226: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 10.64GiB
# 2018-04-05 19:23:48.390709: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 1 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:02:00.0
# totalMemory: 10.91GiB freeMemory: 10.75GiB
# 2018-04-05 19:23:48.393393: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1227] Device peer to peer matrix
# 2018-04-05 19:23:48.393652: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1233] DMA: 0 1
# 2018-04-05 19:23:48.393662: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1243] 0:   Y Y
# 2018-04-05 19:23:48.393666: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1243] 1:   Y Y
# 2018-04-05 19:23:48.393675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0, 1
# 2018-04-05 19:23:48.959961: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10299 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2018-04-05 19:23:48.960829: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10407 MB memory) -> physical GPU (device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1)
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1
# 2018-04-05 19:23:48.962441: I tensorflow/core/common_runtime/direct_session.cc:297] Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1
#
#
# ---------------------------------------
# Script started
# ---------------------------------------
#
# Training U-net model
# 2018-04-05 19:23:49.438202: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0, 1
# 2018-04-05 19:23:49.438409: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10297 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2018-04-05 19:23:49.438657: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10405 MB memory) -> physical GPU (device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1)
# No weights found
# ------------------------------------------
# Always training from scratch at the moment
# ------------------------------------------
# Start training:
# Epoch 1/50
# 2018-04-05 19:24:07.719475: W tensorflow/core/common_runtime/bfc_allocator.cc:219] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.96GiB. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2018-04-05 19:24:07.739716: W tensorflow/core/common_runtime/bfc_allocator.cc:219] Allocator (GPU_1_bfc) ran out of memory trying to allocate 3.96GiB. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 40/40 [==============================] - 32s 791ms/step - loss: 0.7255 - binary_crossentropy: 0.7255 - jaccard_coef_loss: 8.8830 - jaccard_coef: 0.3060 - jaccard_coef_thresholded: 0.3054 - acc: 0.5512 - val_loss: 1.0232 - val_binary_crossentropy: 1.0232 - val_jaccard_coef_loss: 9.3573 - val_jaccard_coef: 0.2824 - val_jaccard_coef_thresholded: 0.3029 - val_acc: 0.4660
# Epoch 2/50
# 40/40 [==============================] - 26s 639ms/step - loss: 0.6774 - binary_crossentropy: 0.6774 - jaccard_coef_loss: 8.7298 - jaccard_coef: 0.2978 - jaccard_coef_thresholded: 0.3212 - acc: 0.6088 - val_loss: 1.1367 - val_binary_crossentropy: 1.1367 - val_jaccard_coef_loss: 9.5273 - val_jaccard_coef: 0.3760 - val_jaccard_coef_thresholded: 0.4413 - val_acc: 0.4418
# Epoch 3/50
# 40/40 [==============================] - 25s 637ms/step - loss: 0.6696 - binary_crossentropy: 0.6696 - jaccard_coef_loss: 8.5942 - jaccard_coef: 0.2968 - jaccard_coef_thresholded: 0.2916 - acc: 0.6055 - val_loss: 0.8255 - val_binary_crossentropy: 0.8255 - val_jaccard_coef_loss: 9.3447 - val_jaccard_coef: 0.2789 - val_jaccard_coef_thresholded: 0.3088 - val_acc: 0.4492
# Epoch 4/50
# 40/40 [==============================] - 26s 641ms/step - loss: 0.6524 - binary_crossentropy: 0.6524 - jaccard_coef_loss: 8.5136 - jaccard_coef: 0.2786 - jaccard_coef_thresholded: 0.2347 - acc: 0.6240 - val_loss: 0.8099 - val_binary_crossentropy: 0.8099 - val_jaccard_coef_loss: 9.5718 - val_jaccard_coef: 0.2837 - val_jaccard_coef_thresholded: 0.3753 - val_acc: 0.3829
# Epoch 5/50
# 40/40 [==============================] - 26s 639ms/step - loss: 0.6555 - binary_crossentropy: 0.6555 - jaccard_coef_loss: 8.2640 - jaccard_coef: 0.3286 - jaccard_coef_thresholded: 0.3857 - acc: 0.6346 - val_loss: 0.8500 - val_binary_crossentropy: 0.8500 - val_jaccard_coef_loss: 9.3354 - val_jaccard_coef: 0.3118 - val_jaccard_coef_thresholded: 0.4219 - val_acc: 0.4332
# Epoch 6/50
# 40/40 [==============================] - 26s 639ms/step - loss: 0.6029 - binary_crossentropy: 0.6029 - jaccard_coef_loss: 7.9260 - jaccard_coef: 0.3387 - jaccard_coef_thresholded: 0.4364 - acc: 0.6532 - val_loss: 0.8931 - val_binary_crossentropy: 0.8931 - val_jaccard_coef_loss: 9.3986 - val_jaccard_coef: 0.3575 - val_jaccard_coef_thresholded: 0.4365 - val_acc: 0.4431
# Epoch 7/50
# 40/40 [==============================] - 26s 644ms/step - loss: 0.6817 - binary_crossentropy: 0.6817 - jaccard_coef_loss: 8.2408 - jaccard_coef: 0.3315 - jaccard_coef_thresholded: 0.3700 - acc: 0.5993 - val_loss: 0.7468 - val_binary_crossentropy: 0.7468 - val_jaccard_coef_loss: 9.4115 - val_jaccard_coef: 0.3107 - val_jaccard_coef_thresholded: 0.4054 - val_acc: 0.4165
# Epoch 8/50
# 40/40 [==============================] - 25s 637ms/step - loss: 0.6815 - binary_crossentropy: 0.6815 - jaccard_coef_loss: 8.8542 - jaccard_coef: 0.2879 - jaccard_coef_thresholded: 0.2175 - acc: 0.5699 - val_loss: 0.7306 - val_binary_crossentropy: 0.7306 - val_jaccard_coef_loss: 9.2706 - val_jaccard_coef: 0.2872 - val_jaccard_coef_thresholded: 0.0287 - val_acc: 0.5827
# Epoch 9/50
# 40/40 [==============================] - 26s 639ms/step - loss: 0.6735 - binary_crossentropy: 0.6735 - jaccard_coef_loss: 8.8288 - jaccard_coef: 0.2988 - jaccard_coef_thresholded: 0.2604 - acc: 0.5701 - val_loss: 0.7415 - val_binary_crossentropy: 0.7415 - val_jaccard_coef_loss: 9.1311 - val_jaccard_coef: 0.3416 - val_jaccard_coef_thresholded: 0.4662 - val_acc: 0.4708
# Epoch 10/50
# 40/40 [==============================] - 26s 639ms/step - loss: 0.5388 - binary_crossentropy: 0.5388 - jaccard_coef_loss: 7.0271 - jaccard_coef: 0.3979 - jaccard_coef_thresholded: 0.6090 - acc: 0.7721 - val_loss: 0.8048 - val_binary_crossentropy: 0.8048 - val_jaccard_coef_loss: 9.2364 - val_jaccard_coef: 0.2734 - val_jaccard_coef_thresholded: 0.0940 - val_acc: 0.5749
# Epoch 11/50
# 40/40 [==============================] - 25s 637ms/step - loss: 0.5472 - binary_crossentropy: 0.5472 - jaccard_coef_loss: 6.7334 - jaccard_coef: 0.4111 - jaccard_coef_thresholded: 0.5479 - acc: 0.7312 - val_loss: 1.0981 - val_binary_crossentropy: 1.0981 - val_jaccard_coef_loss: 9.8247 - val_jaccard_coef: 0.3341 - val_jaccard_coef_thresholded: 0.3939 - val_acc: 0.3982
# Epoch 12/50
# 40/40 [==============================] - 26s 638ms/step - loss: 0.5876 - binary_crossentropy: 0.5876 - jaccard_coef_loss: 7.3685 - jaccard_coef: 0.3806 - jaccard_coef_thresholded: 0.5367 - acc: 0.7062 - val_loss: 0.8521 - val_binary_crossentropy: 0.8521 - val_jaccard_coef_loss: 9.7271 - val_jaccard_coef: 0.3268 - val_jaccard_coef_thresholded: 0.3973 - val_acc: 0.3985
# Epoch 13/50
# 40/40 [==============================] - 26s 640ms/step - loss: 0.5053 - binary_crossentropy: 0.5053 - jaccard_coef_loss: 6.1729 - jaccard_coef: 0.4424 - jaccard_coef_thresholded: 0.5965 - acc: 0.7645 - val_loss: 0.8657 - val_binary_crossentropy: 0.8657 - val_jaccard_coef_loss: 9.2350 - val_jaccard_coef: 0.3358 - val_jaccard_coef_thresholded: 0.4499 - val_acc: 0.4589
# Epoch 14/50
# 40/40 [==============================] - 25s 634ms/step - loss: 0.4266 - binary_crossentropy: 0.4266 - jaccard_coef_loss: 5.5058 - jaccard_coef: 0.4749 - jaccard_coef_thresholded: 0.6447 - acc: 0.8120 - val_loss: 1.1239 - val_binary_crossentropy: 1.1239 - val_jaccard_coef_loss: 10.0276 - val_jaccard_coef: 0.3553 - val_jaccard_coef_thresholded: 0.3965 - val_acc: 0.4014
# Epoch 15/50
# 40/40 [==============================] - 25s 636ms/step - loss: 0.3669 - binary_crossentropy: 0.3669 - jaccard_coef_loss: 4.3719 - jaccard_coef: 0.5794 - jaccard_coef_thresholded: 0.7092 - acc: 0.8420 - val_loss: 1.0395 - val_binary_crossentropy: 1.0395 - val_jaccard_coef_loss: 9.3966 - val_jaccard_coef: 0.3280 - val_jaccard_coef_thresholded: 0.4190 - val_acc: 0.4314
# Epoch 16/50
# 40/40 [==============================] - 25s 634ms/step - loss: 0.4152 - binary_crossentropy: 0.4152 - jaccard_coef_loss: 4.5673 - jaccard_coef: 0.5720 - jaccard_coef_thresholded: 0.6973 - acc: 0.8261 - val_loss: 1.2114 - val_binary_crossentropy: 1.2114 - val_jaccard_coef_loss: 9.4392 - val_jaccard_coef: 0.3971 - val_jaccard_coef_thresholded: 0.4378 - val_acc: 0.4528
# Epoch 17/50
# 40/40 [==============================] - 25s 636ms/step - loss: 0.3655 - binary_crossentropy: 0.3655 - jaccard_coef_loss: 4.2836 - jaccard_coef: 0.5642 - jaccard_coef_thresholded: 0.6912 - acc: 0.8452 - val_loss: 0.6983 - val_binary_crossentropy: 0.6983 - val_jaccard_coef_loss: 8.9826 - val_jaccard_coef: 0.2788 - val_jaccard_coef_thresholded: 0.0076 - val_acc: 0.5717
# Epoch 18/50
# 40/40 [==============================] - 25s 635ms/step - loss: 0.4967 - binary_crossentropy: 0.4967 - jaccard_coef_loss: 5.3545 - jaccard_coef: 0.4864 - jaccard_coef_thresholded: 0.6028 - acc: 0.7830 - val_loss: 1.0320 - val_binary_crossentropy: 1.0320 - val_jaccard_coef_loss: 9.5226 - val_jaccard_coef: 0.3111 - val_jaccard_coef_thresholded: 0.3949 - val_acc: 0.4024
# Epoch 19/50
# 40/40 [==============================] - 25s 631ms/step - loss: 0.3634 - binary_crossentropy: 0.3634 - jaccard_coef_loss: 4.7682 - jaccard_coef: 0.5215 - jaccard_coef_thresholded: 0.6931 - acc: 0.8442 - val_loss: 1.5427 - val_binary_crossentropy: 1.5427 - val_jaccard_coef_loss: 10.2502 - val_jaccard_coef: 0.3622 - val_jaccard_coef_thresholded: 0.3847 - val_acc: 0.3998
# Epoch 20/50
# 40/40 [==============================] - 25s 635ms/step - loss: 0.4696 - binary_crossentropy: 0.4696 - jaccard_coef_loss: 4.6455 - jaccard_coef: 0.5662 - jaccard_coef_thresholded: 0.6763 - acc: 0.8116 - val_loss: 1.2857 - val_binary_crossentropy: 1.2857 - val_jaccard_coef_loss: 9.6767 - val_jaccard_coef: 0.3738 - val_jaccard_coef_thresholded: 0.4177 - val_acc: 0.4304
# Epoch 21/50
# 40/40 [==============================] - 25s 634ms/step - loss: 0.3772 - binary_crossentropy: 0.3772 - jaccard_coef_loss: 4.6936 - jaccard_coef: 0.5455 - jaccard_coef_thresholded: 0.7029 - acc: 0.8428 - val_loss: 1.9545 - val_binary_crossentropy: 1.9545 - val_jaccard_coef_loss: 9.6651 - val_jaccard_coef: 0.4268 - val_jaccard_coef_thresholded: 0.4347 - val_acc: 0.4488
# Epoch 22/50
# 40/40 [==============================] - 25s 635ms/step - loss: 0.2826 - binary_crossentropy: 0.2826 - jaccard_coef_loss: 3.5114 - jaccard_coef: 0.6235 - jaccard_coef_thresholded: 0.7609 - acc: 0.8892 - val_loss: 2.4587 - val_binary_crossentropy: 2.4587 - val_jaccard_coef_loss: 10.1279 - val_jaccard_coef: 0.4053 - val_jaccard_coef_thresholded: 0.4092 - val_acc: 0.4251
# Epoch 23/50
# 40/40 [==============================] - 25s 634ms/step - loss: 0.4654 - binary_crossentropy: 0.4654 - jaccard_coef_loss: 4.5649 - jaccard_coef: 0.5569 - jaccard_coef_thresholded: 0.6450 - acc: 0.8078 - val_loss: 2.8367 - val_binary_crossentropy: 2.8367 - val_jaccard_coef_loss: 10.1515 - val_jaccard_coef: 0.4080 - val_jaccard_coef_thresholded: 0.4092 - val_acc: 0.4244
# Epoch 24/50
# 40/40 [==============================] - 25s 635ms/step - loss: 0.4691 - binary_crossentropy: 0.4691 - jaccard_coef_loss: 5.5784 - jaccard_coef: 0.4791 - jaccard_coef_thresholded: 0.6170 - acc: 0.7921 - val_loss: 4.5898 - val_binary_crossentropy: 4.5898 - val_jaccard_coef_loss: 9.3177 - val_jaccard_coef: 0.4588 - val_jaccard_coef_thresholded: 0.4588 - val_acc: 0.4711
# Epoch 25/50
# 40/40 [==============================] - 25s 635ms/step - loss: 0.4847 - binary_crossentropy: 0.4847 - jaccard_coef_loss: 5.7279 - jaccard_coef: 0.4689 - jaccard_coef_thresholded: 0.6418 - acc: 0.7947 - val_loss: 0.7316 - val_binary_crossentropy: 0.7316 - val_jaccard_coef_loss: 9.0247 - val_jaccard_coef: 0.2410 - val_jaccard_coef_thresholded: 0.0267 - val_acc: 0.6163
# Epoch 26/50
# 40/40 [==============================] - 25s 636ms/step - loss: 0.4515 - binary_crossentropy: 0.4515 - jaccard_coef_loss: 4.8498 - jaccard_coef: 0.5324 - jaccard_coef_thresholded: 0.6579 - acc: 0.8153 - val_loss: 0.8423 - val_binary_crossentropy: 0.8423 - val_jaccard_coef_loss: 8.7683 - val_jaccard_coef: 0.1739 - val_jaccard_coef_thresholded: 0.0295 - val_acc: 0.6112
# Epoch 27/50
# 40/40 [==============================] - 26s 641ms/step - loss: 0.5173 - binary_crossentropy: 0.5173 - jaccard_coef_loss: 5.8722 - jaccard_coef: 0.4524 - jaccard_coef_thresholded: 0.5526 - acc: 0.7609 - val_loss: 0.8371 - val_binary_crossentropy: 0.8371 - val_jaccard_coef_loss: 9.3122 - val_jaccard_coef: 0.2359 - val_jaccard_coef_thresholded: 0.0039 - val_acc: 0.5507
# Epoch 28/50
# 40/40 [==============================] - 25s 637ms/step - loss: 0.3718 - binary_crossentropy: 0.3718 - jaccard_coef_loss: 4.9679 - jaccard_coef: 0.5123 - jaccard_coef_thresholded: 0.7077 - acc: 0.8540 - val_loss: 0.8901 - val_binary_crossentropy: 0.8901 - val_jaccard_coef_loss: 9.3002 - val_jaccard_coef: 0.2165 - val_jaccard_coef_thresholded: 0.0065 - val_acc: 0.5415
# Epoch 29/50
# 40/40 [==============================] - 25s 636ms/step - loss: 0.3596 - binary_crossentropy: 0.3596 - jaccard_coef_loss: 4.2576 - jaccard_coef: 0.5905 - jaccard_coef_thresholded: 0.7276 - acc: 0.8492 - val_loss: 0.7257 - val_binary_crossentropy: 0.7257 - val_jaccard_coef_loss: 9.0410 - val_jaccard_coef: 0.2471 - val_jaccard_coef_thresholded: 1.5659e-05 - val_acc: 0.5946
# Epoch 30/50
# 40/40 [==============================] - 25s 636ms/step - loss: 0.4034 - binary_crossentropy: 0.4034 - jaccard_coef_loss: 4.2709 - jaccard_coef: 0.6004 - jaccard_coef_thresholded: 0.7107 - acc: 0.8368 - val_loss: 0.8237 - val_binary_crossentropy: 0.8237 - val_jaccard_coef_loss: 9.3363 - val_jaccard_coef: 0.3251 - val_jaccard_coef_thresholded: 0.4182 - val_acc: 0.4308
# Epoch 31/50
# 40/40 [==============================] - 25s 633ms/step - loss: 0.3704 - binary_crossentropy: 0.3704 - jaccard_coef_loss: 4.4415 - jaccard_coef: 0.5569 - jaccard_coef_thresholded: 0.6986 - acc: 0.8481 - val_loss: 3.0112 - val_binary_crossentropy: 3.0112 - val_jaccard_coef_loss: 9.2520 - val_jaccard_coef: 0.4622 - val_jaccard_coef_thresholded: 0.4629 - val_acc: 0.4744
# Epoch 32/50
# 40/40 [==============================] - 25s 633ms/step - loss: 0.3794 - binary_crossentropy: 0.3794 - jaccard_coef_loss: 4.2588 - jaccard_coef: 0.5855 - jaccard_coef_thresholded: 0.7064 - acc: 0.8435 - val_loss: 2.1126 - val_binary_crossentropy: 2.1126 - val_jaccard_coef_loss: 11.0312 - val_jaccard_coef: 0.0118 - val_jaccard_coef_thresholded: 0.0037 - val_acc: 0.5939
# Epoch 33/50
# 40/40 [==============================] - 25s 634ms/step - loss: 0.2912 - binary_crossentropy: 0.2912 - jaccard_coef_loss: 3.5365 - jaccard_coef: 0.6373 - jaccard_coef_thresholded: 0.7531 - acc: 0.8740 - val_loss: 1.0280 - val_binary_crossentropy: 1.0280 - val_jaccard_coef_loss: 9.4287 - val_jaccard_coef: 0.2783 - val_jaccard_coef_thresholded: 0.3835 - val_acc: 0.3893
# Epoch 34/50
# 40/40 [==============================] - 25s 637ms/step - loss: 0.8028 - binary_crossentropy: 0.8028 - jaccard_coef_loss: 8.2044 - jaccard_coef: 0.3384 - jaccard_coef_thresholded: 0.3380 - acc: 0.5905 - val_loss: 6.5426 - val_binary_crossentropy: 6.5426 - val_jaccard_coef_loss: 19.0371 - val_jaccard_coef: 0.0236 - val_jaccard_coef_thresholded: 0.0236 - val_acc: 0.5899
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# Epoch 35/50
# 40/40 [==============================] - 26s 639ms/step - loss: 0.4976 - binary_crossentropy: 0.4976 - jaccard_coef_loss: 6.9875 - jaccard_coef: 0.3768 - jaccard_coef_thresholded: 0.6216 - acc: 0.8039 - val_loss: 7.4248 - val_binary_crossentropy: 7.4248 - val_jaccard_coef_loss: 18.2457 - val_jaccard_coef: 0.0185 - val_jaccard_coef_thresholded: 0.0185 - val_acc: 0.5387
# Epoch 36/50
# 40/40 [==============================] - 25s 630ms/step - loss: 0.4330 - binary_crossentropy: 0.4330 - jaccard_coef_loss: 6.0746 - jaccard_coef: 0.4448 - jaccard_coef_thresholded: 0.6835 - acc: 0.8352 - val_loss: 0.7515 - val_binary_crossentropy: 0.7515 - val_jaccard_coef_loss: 9.1682 - val_jaccard_coef: 0.2581 - val_jaccard_coef_thresholded: 0.0023 - val_acc: 0.5735
# Epoch 37/50
# 40/40 [==============================] - 25s 636ms/step - loss: 0.3709 - binary_crossentropy: 0.3709 - jaccard_coef_loss: 5.2332 - jaccard_coef: 0.4953 - jaccard_coef_thresholded: 0.7232 - acc: 0.8635 - val_loss: 0.8018 - val_binary_crossentropy: 0.8018 - val_jaccard_coef_loss: 9.2239 - val_jaccard_coef: 0.2540 - val_jaccard_coef_thresholded: 0.0086 - val_acc: 0.5632
# Epoch 38/50
# 40/40 [==============================] - 25s 633ms/step - loss: 0.3457 - binary_crossentropy: 0.3457 - jaccard_coef_loss: 4.7290 - jaccard_coef: 0.5408 - jaccard_coef_thresholded: 0.7298 - acc: 0.8630 - val_loss: 0.7954 - val_binary_crossentropy: 0.7954 - val_jaccard_coef_loss: 9.1164 - val_jaccard_coef: 0.2663 - val_jaccard_coef_thresholded: 0.0104 - val_acc: 0.5587
# Epoch 39/50
# 40/40 [==============================] - 25s 634ms/step - loss: 0.3239 - binary_crossentropy: 0.3239 - jaccard_coef_loss: 4.3466 - jaccard_coef: 0.5661 - jaccard_coef_thresholded: 0.7329 - acc: 0.8696 - val_loss: 6.8712 - val_binary_crossentropy: 6.8712 - val_jaccard_coef_loss: 26.0137 - val_jaccard_coef: 0.0051 - val_jaccard_coef_thresholded: 0.0051 - val_acc: 0.5736
# Epoch 40/50
# 40/40 [==============================] - 25s 636ms/step - loss: 0.3951 - binary_crossentropy: 0.3951 - jaccard_coef_loss: 4.7748 - jaccard_coef: 0.5239 - jaccard_coef_thresholded: 0.6639 - acc: 0.8349 - val_loss: 6.4181 - val_binary_crossentropy: 6.4181 - val_jaccard_coef_loss: 22.4307 - val_jaccard_coef: 0.0326 - val_jaccard_coef_thresholded: 0.0326 - val_acc: 0.6017
# Epoch 41/50
# 40/40 [==============================] - 25s 637ms/step - loss: 0.3139 - binary_crossentropy: 0.3139 - jaccard_coef_loss: 4.0196 - jaccard_coef: 0.5982 - jaccard_coef_thresholded: 0.7642 - acc: 0.8798 - val_loss: 0.8132 - val_binary_crossentropy: 0.8132 - val_jaccard_coef_loss: 9.0599 - val_jaccard_coef: 0.2529 - val_jaccard_coef_thresholded: 0.0203 - val_acc: 0.6109
# Epoch 42/50
# 40/40 [==============================] - 26s 639ms/step - loss: 0.3286 - binary_crossentropy: 0.3286 - jaccard_coef_loss: 4.0874 - jaccard_coef: 0.5926 - jaccard_coef_thresholded: 0.7248 - acc: 0.8598 - val_loss: 7.3755 - val_binary_crossentropy: 7.3755 - val_jaccard_coef_loss: 30.4290 - val_jaccard_coef: 0.0090 - val_jaccard_coef_thresholded: 0.0090 - val_acc: 0.5423
# Epoch 43/50
# 40/40 [==============================] - 25s 637ms/step - loss: 0.3013 - binary_crossentropy: 0.3013 - jaccard_coef_loss: 3.7609 - jaccard_coef: 0.6247 - jaccard_coef_thresholded: 0.7621 - acc: 0.8774 - val_loss: 7.2381 - val_binary_crossentropy: 7.2381 - val_jaccard_coef_loss: 28.2404 - val_jaccard_coef: 0.0035 - val_jaccard_coef_thresholded: 0.0035 - val_acc: 0.5508
# Epoch 44/50
# 40/40 [==============================] - 25s 636ms/step - loss: 0.4870 - binary_crossentropy: 0.4870 - jaccard_coef_loss: 4.8770 - jaccard_coef: 0.5397 - jaccard_coef_thresholded: 0.6437 - acc: 0.8054 - val_loss: 0.6986 - val_binary_crossentropy: 0.6986 - val_jaccard_coef_loss: 6.9751 - val_jaccard_coef: 0.3666 - val_jaccard_coef_thresholded: 0.7070 - val_acc: 0.8755
# Epoch 45/50
# 40/40 [==============================] - 25s 632ms/step - loss: 0.2820 - binary_crossentropy: 0.2820 - jaccard_coef_loss: 3.6796 - jaccard_coef: 0.6273 - jaccard_coef_thresholded: 0.7951 - acc: 0.8984 - val_loss: 0.8126 - val_binary_crossentropy: 0.8126 - val_jaccard_coef_loss: 9.1385 - val_jaccard_coef: 0.2651 - val_jaccard_coef_thresholded: 0.0097 - val_acc: 0.5819
# Epoch 46/50
# 40/40 [==============================] - 25s 635ms/step - loss: 0.5522 - binary_crossentropy: 0.5522 - jaccard_coef_loss: 5.8742 - jaccard_coef: 0.4715 - jaccard_coef_thresholded: 0.5532 - acc: 0.7549 - val_loss: 7.3271 - val_binary_crossentropy: 7.3271 - val_jaccard_coef_loss: 33.5837 - val_jaccard_coef: 0.0035 - val_jaccard_coef_thresholded: 0.0035 - val_acc: 0.5453
# Epoch 47/50
# 40/40 [==============================] - 25s 634ms/step - loss: 0.2732 - binary_crossentropy: 0.2732 - jaccard_coef_loss: 3.6769 - jaccard_coef: 0.6199 - jaccard_coef_thresholded: 0.7958 - acc: 0.9021 - val_loss: 6.4177 - val_binary_crossentropy: 6.4177 - val_jaccard_coef_loss: 29.6467 - val_jaccard_coef: 0.0156 - val_jaccard_coef_thresholded: 0.0156 - val_acc: 0.6017
# Epoch 48/50
# 40/40 [==============================] - 25s 631ms/step - loss: 0.2948 - binary_crossentropy: 0.2948 - jaccard_coef_loss: 3.6239 - jaccard_coef: 0.6280 - jaccard_coef_thresholded: 0.7540 - acc: 0.8759 - val_loss: 6.6926 - val_binary_crossentropy: 6.6926 - val_jaccard_coef_loss: 19.9778 - val_jaccard_coef: 0.0240 - val_jaccard_coef_thresholded: 0.0240 - val_acc: 0.5848
# Epoch 49/50
# 40/40 [==============================] - 26s 638ms/step - loss: 0.7715 - binary_crossentropy: 0.7715 - jaccard_coef_loss: 7.5353 - jaccard_coef: 0.3786 - jaccard_coef_thresholded: 0.4331 - acc: 0.6452 - val_loss: 6.9961 - val_binary_crossentropy: 6.9961 - val_jaccard_coef_loss: 40.0417 - val_jaccard_coef: 1.8961e-06 - val_jaccard_coef_thresholded: 1.8961e-06 - val_acc: 0.5659
# Epoch 50/50
# 40/40 [==============================] - 25s 636ms/step - loss: 0.3680 - binary_crossentropy: 0.3680 - jaccard_coef_loss: 4.8278 - jaccard_coef: 0.5129 - jaccard_coef_thresholded: 0.6924 - acc: 0.8540 - val_loss: 0.8978 - val_binary_crossentropy: 0.8978 - val_jaccard_coef_loss: 9.2107 - val_jaccard_coef: 0.2892 - val_jaccard_coef_thresholded: 0.0061 - val_acc: 0.5540
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 8.000000379979611e-05.
# ------------------------------------------
# Evaluate model on test data set:
# ------------------------------------------
# /home/jhj/phd/GitProjects/SentinelSemanticSegmentation/src/models/model_utils.py:148: RuntimeWarning: invalid value encountered in double_scalars
#   pixel_jaccard[j, i] = tp[j, i] / (tp[j, i] + fp[j, i] + fn[j, i])
# Testing product  0 : LC80420082013220LGN00
# Prediction finished in      : 34.933695793151855s
# ------------------------------------------
# Testing product  1 : LC81330312013202LGN00
# Prediction finished in      : 25.94622039794922s
# ------------------------------------------
# Testing product  2 : LC81360302014162LGN00
# Prediction finished in      : 27.27256464958191s
# ------------------------------------------
# Testing product  3 : LC81550082014263LGN00
# Prediction finished in      : 34.45898151397705s
# ------------------------------------------
# Testing product  4 : LC81570452014213LGN00
# Prediction finished in      : 25.168070793151855s
# ------------------------------------------
# Testing product  5 : LC81640502013179LGN01
# Prediction finished in      : 25.458171606063843s
# ------------------------------------------
# Testing product  6 : LC80070662014234LGN00
# Prediction finished in      : 25.634997129440308s
# ------------------------------------------
# Testing product  7 : LC80160502014041LGN00
# Prediction finished in      : 25.17728281021118s
# ------------------------------------------
# Testing product  8 : LC81170272014189LGN00
# Prediction finished in      : 27.273375988006592s
# ------------------------------------------
# Testing product  9 : LC81310182013108LGN01
# Prediction finished in      : 26.58402943611145s
# ------------------------------------------
# Testing product  10 : LC81800662014230LGN00
# Prediction finished in      : 25.6274197101593s
# ------------------------------------------
# Testing product  11 : LC82290572014141LGN00
# Prediction finished in      : 25.621997833251953s
# ------------------------------------------
# Testing product  12 : LC80290372013257LGN00
# Prediction finished in      : 26.35741376876831s
# ------------------------------------------
# Testing product  13 : LC81220312014208LGN00
# Prediction finished in      : 26.190940856933594s
# ------------------------------------------
# Testing product  14 : LC81220422014096LGN00
# Prediction finished in      : 26.188140153884888s
# ------------------------------------------
# Testing product  15 : LC81490432014141LGN00
# Prediction finished in      : 26.37226176261902s
# ------------------------------------------
# Testing product  16 : LC81510262014139LGN00
# Prediction finished in      : 26.913357496261597s
# ------------------------------------------
# Testing product  17 : LC81750512013208LGN00
# Prediction finished in      : 25.580801248550415s
# ------------------------------------------
# Testing product  18 : LC80010732013109LGN00
# Prediction finished in      : 24.665446758270264s
# ------------------------------------------
# Testing product  19 : LC80350192014190LGN00
# Prediction finished in      : 29.48546862602234s
# ------------------------------------------
# Testing product  20 : LC80750172013163LGN00
# Prediction finished in      : 27.698573350906372s
# ------------------------------------------
# Testing product  21 : LC80760182013170LGN00
# Prediction finished in      : 27.97904324531555s
# ------------------------------------------
# Testing product  22 : LC81020802014100LGN00
# Prediction finished in      : 25.629125356674194s
# ------------------------------------------
# Testing product  23 : LC81600462013215LGN00
# Prediction finished in      : 26.246288537979126s
# ------------------------------------------
# Testing product  24 : LC80060102014147LGN00
# Prediction finished in      : 31.262553691864014s
# ------------------------------------------
# Testing product  25 : LC80250022014232LGN00
# Prediction finished in      : 34.145667552948s
# ------------------------------------------
# Testing product  26 : LC80841202014309LGN00
# Prediction finished in      : 28.057605504989624s
# ------------------------------------------
# Testing product  27 : LC82171112014297LGN00
# Prediction finished in      : 36.16734337806702s
# ------------------------------------------
# Testing product  28 : LC82271192014287LGN00
# Prediction finished in      : 32.95170068740845s
# ------------------------------------------
# Testing product  29 : LC82320072014226LGN00
# Prediction finished in      : 33.83200788497925s
# ------------------------------------------
# Testing product  30 : LC80170312013157LGN00
# Prediction finished in      : 24.600669860839844s
# ------------------------------------------
# Testing product  31 : LC80410372013357LGN00
# Prediction finished in      : 26.33722186088562s
# ------------------------------------------
# Testing product  32 : LC80460282014171LGN00
# Prediction finished in      : 26.518101692199707s
# ------------------------------------------
# Testing product  33 : LC81620432014072LGN00
# Prediction finished in      : 25.41910982131958s
# ------------------------------------------
# Testing product  34 : LC81770262013254LGN00
# Prediction finished in      : 28.86809253692627s
# ------------------------------------------
# Testing product  35 : LC81920192013103LGN01
# Prediction finished in      : 25.332677364349365s
# ------------------------------------------
# Testing product  36 : LC80120552013202LGN00
# Prediction finished in      : 25.517099142074585s
# ------------------------------------------
# Testing product  37 : LC80180082014215LGN00
# Prediction finished in      : 32.988938093185425s
# ------------------------------------------
# Testing product  38 : LC80430122014214LGN00
# Prediction finished in      : 31.07290506362915s
# ------------------------------------------
# Testing product  39 : LC81130632014241LGN00
# Prediction finished in      : 25.21819758415222s
# ------------------------------------------
# Testing product  40 : LC81240462014238LGN00
# Prediction finished in      : 25.832761764526367s
# ------------------------------------------
# Testing product  41 : LC82150712013152LGN00
# Prediction finished in      : 24.49573063850403s
# ------------------------------------------
# Testing product  42 : LC80310202013223LGN00
# Prediction finished in      : 29.515347242355347s
# ------------------------------------------
# Testing product  43 : LC80340192014167LGN00
# Prediction finished in      : 28.092852115631104s
# ------------------------------------------
# Testing product  44 : LC81020152014036LGN00
# Prediction finished in      : 29.29188346862793s
# ------------------------------------------
# Testing product  45 : LC81030162014107LGN00
# Prediction finished in      : 29.357411861419678s
# ------------------------------------------
# Testing product  46 : LC81080162013171LGN00
# Prediction finished in      : 28.198564052581787s
# ------------------------------------------
# Testing product  47 : LC81080182014238LGN00
# Prediction finished in      : 28.112540245056152s
# Training U-net model
# ------------------------------------------
# Always training from scratch at the moment
# ------------------------------------------
# Start training:
# Epoch 1/50
# Traceback (most recent call last):
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1361, in _do_call
#     return fn(*args)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1340, in _run_fn
#     target_list, status, run_metadata)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.InternalError: CUB reduce errorinvalid configuration argument
# 	 [[Node: metrics_1/binary_crossentropy/Mean_1 = Mean[T=DT_FLOAT, Tidx=DT_INT32, keep_dims=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"](metrics_1/binary_crossentropy/Mean, metrics_1/binary_crossentropy/Const_1)]]
# 	 [[Node: training_1/Adam/gradients/conv2d_57_1/concat_grad/Slice_1/_4939 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:1", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_4775_training_1/Adam/gradients/conv2d_57_1/concat_grad/Slice_1", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:1"]()]]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jhj/phd/GitProjects/SentinelSemanticSegmentation/SentinelSemanticSegmentation.py", line 149, in <module>
#     model.train(args.num_gpus, params)
#   File "/home/jhj/phd/GitProjects/SentinelSemanticSegmentation/src/models/Unet.py", line 216, in train
#     validation_steps=10)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/engine/training.py", line 2224, in fit_generator
#     class_weight=class_weight)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/engine/training.py", line 1883, in train_on_batch
#     outputs = self.train_function(ins)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 2478, in __call__
#     **self.session_kwargs)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 905, in run
#     run_metadata_ptr)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1137, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1355, in _do_run
#     options, run_metadata)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1374, in _do_call
#     raise type(e)(node_def, op, message)
# tensorflow.python.framework.errors_impl.InternalError: CUB reduce errorinvalid configuration argument
# 	 [[Node: metrics_1/binary_crossentropy/Mean_1 = Mean[T=DT_FLOAT, Tidx=DT_INT32, keep_dims=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"](metrics_1/binary_crossentropy/Mean, metrics_1/binary_crossentropy/Const_1)]]
# 	 [[Node: training_1/Adam/gradients/conv2d_57_1/concat_grad/Slice_1/_4939 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:1", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_4775_training_1/Adam/gradients/conv2d_57_1/concat_grad/Slice_1", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:1"]()]]
#
# Caused by op 'metrics_1/binary_crossentropy/Mean_1', defined at:
#   File "/home/jhj/phd/GitProjects/SentinelSemanticSegmentation/SentinelSemanticSegmentation.py", line 149, in <module>
#     model.train(args.num_gpus, params)
#   File "/home/jhj/phd/GitProjects/SentinelSemanticSegmentation/src/models/Unet.py", line 194, in train
#     metrics=['binary_crossentropy', jaccard_coef_loss, jaccard_coef, jaccard_coef_thresholded, 'accuracy'])
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/engine/training.py", line 934, in compile
#     handle_metrics(output_metrics)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/engine/training.py", line 913, in handle_metrics
#     mask=masks[i])
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/engine/training.py", line 447, in weighted
#     return K.mean(score_array)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 1367, in mean
#     return tf.reduce_mean(x, axis, keepdims)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 432, in new_func
#     return func(*args, **kwargs)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py", line 1512, in reduce_mean
#     name=name))
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py", line 2635, in _mean
#     name=name)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3271, in create_op
#     op_def=op_def)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1650, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InternalError (see above for traceback): CUB reduce errorinvalid configuration argument
# 	 [[Node: metrics_1/binary_crossentropy/Mean_1 = Mean[T=DT_FLOAT, Tidx=DT_INT32, keep_dims=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"](metrics_1/binary_crossentropy/Mean, metrics_1/binary_crossentropy/Const_1)]]
# 	 [[Node: training_1/Adam/gradients/conv2d_57_1/concat_grad/Slice_1/_4939 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:1", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_4775_training_1/Adam/gradients/conv2d_57_1/concat_grad/Slice_1", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:1"]()]]
# /home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 2018-04-05 20:08:05.332937: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-04-05 20:08:05.478490: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 10.64GiB
# 2018-04-05 20:08:05.583091: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 1 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:02:00.0
# totalMemory: 10.91GiB freeMemory: 10.75GiB
# 2018-04-05 20:08:05.585656: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1227] Device peer to peer matrix
# 2018-04-05 20:08:05.585789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1233] DMA: 0 1
# 2018-04-05 20:08:05.585797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1243] 0:   Y Y
# 2018-04-05 20:08:05.585802: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1243] 1:   Y Y
# 2018-04-05 20:08:05.585810: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0, 1
# 2018-04-05 20:08:06.105753: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10299 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2018-04-05 20:08:06.106586: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10407 MB memory) -> physical GPU (device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1)
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1
# 2018-04-05 20:08:06.109548: I tensorflow/core/common_runtime/direct_session.cc:297] Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1
#
#
# ---------------------------------------
# Script started
# ---------------------------------------
#
# Training U-net model
# 2018-04-05 20:08:06.720918: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0, 1
# 2018-04-05 20:08:06.721127: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10297 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2018-04-05 20:08:06.721377: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10405 MB memory) -> physical GPU (device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1)
# No weights found
# ------------------------------------------
# Always training from scratch at the moment
# ------------------------------------------
# Start training:
# Epoch 1/50
# 2018-04-05 20:08:24.607822: W tensorflow/core/common_runtime/bfc_allocator.cc:219] Allocator (GPU_1_bfc) ran out of memory trying to allocate 3.96GiB. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2018-04-05 20:08:24.618764: W tensorflow/core/common_runtime/bfc_allocator.cc:219] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.96GiB. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 40/40 [==============================] - 31s 773ms/step - loss: 0.7207 - binary_crossentropy: 0.7207 - jaccard_coef_loss: 8.7672 - jaccard_coef: 0.3093 - jaccard_coef_thresholded: 0.3376 - acc: 0.5723 - val_loss: 6.5596 - val_binary_crossentropy: 6.5596 - val_jaccard_coef_loss: 25.0392 - val_jaccard_coef: 9.6076e-09 - val_jaccard_coef_thresholded: 3.8369e-16 - val_acc: 0.5927
# Epoch 2/50
# 40/40 [==============================] - 25s 633ms/step - loss: 0.6374 - binary_crossentropy: 0.6374 - jaccard_coef_loss: 8.1995 - jaccard_coef: 0.3210 - jaccard_coef_thresholded: 0.4187 - acc: 0.6379 - val_loss: 0.8045 - val_binary_crossentropy: 0.8045 - val_jaccard_coef_loss: 9.1363 - val_jaccard_coef: 0.3099 - val_jaccard_coef_thresholded: 0.2505 - val_acc: 0.5125
# Epoch 3/50
# 40/40 [==============================] - 25s 637ms/step - loss: 0.6869 - binary_crossentropy: 0.6869 - jaccard_coef_loss: 8.7523 - jaccard_coef: 0.2904 - jaccard_coef_thresholded: 0.2772 - acc: 0.5934 - val_loss: 0.8716 - val_binary_crossentropy: 0.8716 - val_jaccard_coef_loss: 9.5978 - val_jaccard_coef: 0.3205 - val_jaccard_coef_thresholded: 0.3938 - val_acc: 0.3950
# Epoch 4/50
# 40/40 [==============================] - 26s 638ms/step - loss: 0.6537 - binary_crossentropy: 0.6537 - jaccard_coef_loss: 8.4539 - jaccard_coef: 0.2853 - jaccard_coef_thresholded: 0.3219 - acc: 0.6038 - val_loss: 1.5722 - val_binary_crossentropy: 1.5722 - val_jaccard_coef_loss: 9.8741 - val_jaccard_coef: 0.0314 - val_jaccard_coef_thresholded: 0.0032 - val_acc: 0.6063
# Epoch 5/50
# 40/40 [==============================] - 25s 636ms/step - loss: 0.6642 - binary_crossentropy: 0.6642 - jaccard_coef_loss: 8.5062 - jaccard_coef: 0.3138 - jaccard_coef_thresholded: 0.3695 - acc: 0.6080 - val_loss: 2.5727 - val_binary_crossentropy: 2.5727 - val_jaccard_coef_loss: 9.9273 - val_jaccard_coef: 0.4309 - val_jaccard_coef_thresholded: 0.4341 - val_acc: 0.4387
# Epoch 6/50
# 40/40 [==============================] - 26s 640ms/step - loss: 0.6454 - binary_crossentropy: 0.6454 - jaccard_coef_loss: 8.3463 - jaccard_coef: 0.3120 - jaccard_coef_thresholded: 0.4162 - acc: 0.6427 - val_loss: 1.1082 - val_binary_crossentropy: 1.1082 - val_jaccard_coef_loss: 9.4622 - val_jaccard_coef: 0.4067 - val_jaccard_coef_thresholded: 0.4416 - val_acc: 0.4547
# Epoch 7/50
# 40/40 [==============================] - 26s 644ms/step - loss: 0.6321 - binary_crossentropy: 0.6321 - jaccard_coef_loss: 8.2965 - jaccard_coef: 0.3185 - jaccard_coef_thresholded: 0.4340 - acc: 0.6571 - val_loss: 0.9909 - val_binary_crossentropy: 0.9909 - val_jaccard_coef_loss: 9.8009 - val_jaccard_coef: 0.3683 - val_jaccard_coef_thresholded: 0.4122 - val_acc: 0.4176
# Epoch 8/50
# 40/40 [==============================] - 26s 638ms/step - loss: 0.6299 - binary_crossentropy: 0.6299 - jaccard_coef_loss: 8.1189 - jaccard_coef: 0.3264 - jaccard_coef_thresholded: 0.4333 - acc: 0.6507 - val_loss: 0.6933 - val_binary_crossentropy: 0.6933 - val_jaccard_coef_loss: 9.1946 - val_jaccard_coef: 0.2864 - val_jaccard_coef_thresholded: 0.0299 - val_acc: 0.5815
# Epoch 9/50
# 40/40 [==============================] - 25s 636ms/step - loss: 0.6618 - binary_crossentropy: 0.6618 - jaccard_coef_loss: 8.4109 - jaccard_coef: 0.3162 - jaccard_coef_thresholded: 0.3938 - acc: 0.6188 - val_loss: 0.7454 - val_binary_crossentropy: 0.7454 - val_jaccard_coef_loss: 9.1189 - val_jaccard_coef: 0.3657 - val_jaccard_coef_thresholded: 0.4675 - val_acc: 0.4786
# Epoch 10/50
# 40/40 [==============================] - 25s 635ms/step - loss: 0.6434 - binary_crossentropy: 0.6434 - jaccard_coef_loss: 8.4336 - jaccard_coef: 0.3068 - jaccard_coef_thresholded: 0.3785 - acc: 0.6261 - val_loss: 0.7249 - val_binary_crossentropy: 0.7249 - val_jaccard_coef_loss: 9.3804 - val_jaccard_coef: 0.2930 - val_jaccard_coef_thresholded: 0.4003 - val_acc: 0.4054
# Epoch 11/50
# 30/40 [=====================>........] - ETA: 5s - loss: 0.6188 - binary_crossentropy: 0.6188 - jaccard_coef_loss: 8.1077 - jaccard_coef: 0.3236 - jaccard_coef_thresholded: 0.4396 - acc: 0.6580^C
# ^C
# Traceback (most recent call last):
#   File "/home/jhj/phd/GitProjects/SentinelSemanticSegmentation/SentinelSemanticSegmentation.py", line 22, in <module>
#     from src.models.params import get_params
#   File "/home/jhj/phd/GitProjects/SentinelSemanticSegmentation/src/models/params.py", line 2, in <module>
#     import tensorflow as tf
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/__init__.py", line 24, in <module>
#     from tensorflow.python import *
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/__init__.py", line 81, in <module>
#     from tensorflow.python import keras
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/keras/__init__.py", line 26, in <module>
#     from tensorflow.python.keras import activations
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/keras/activations/__init__.py", line 22, in <module>
#     from tensorflow.python.keras._impl.keras.activations import elu
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras import activations
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/activations.py", line 24, in <module>
#     from tensorflow.python.keras._impl.keras.utils.generic_utils import deserialize_keras_object
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/utils/__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras.utils.data_utils import GeneratorEnqueuer
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/utils/data_utils.py", line 24, in <module>
#     import multiprocessing
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/multiprocessing/__init__.py", line 16, in <module>
#     from . import context
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/multiprocessing/context.py", line 6, in <module>
#     from . import reduction
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/multiprocessing/reduction.py", line 244, in <module>
#     class AbstractReducer(metaclass=ABCMeta):
# ...
#     line = next(iter(version_lines), '')
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pkg_resources/__init__.py", line 2627, in _get_metadata
#     for line in self.get_metadata_lines(name):
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pkg_resources/__init__.py", line 2262, in yield_lines
#     for s in strs.splitlines():
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "/home/jhj/phd/GitProjects/SentinelSemanticSegmentation/SentinelSemanticSegmentation.py", line 22, in <module>
#     from src.models.params import get_params
#   File "/home/jhj/phd/GitProjects/SentinelSemanticSegmentation/src/models/params.py", line 2, in <module>
#     import tensorflow as tf
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/__init__.py", line 24, in <module>
#     from tensorflow.python import *
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/__init__.py", line 52, in <module>
#     from tensorflow.core.framework.graph_pb2 import *
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/core/framework/graph_pb2.py", line 6, in <module>
#     from google.protobuf import descriptor as _descriptor
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/google/protobuf/__init__.py", line 37, in <module>
#     __import__('pkg_resources').declare_namespace(__name__)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3088, in <module>
#     @_call_aside
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3072, in _call_aside
#     f(*args, **kwargs)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3116, in _initialize_master_working_set
#     for dist in working_set
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3116, in <genexpr>
#     for dist in working_set
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pkg_resources/__init__.py", line 2636, in activate
#     fixup_namespace_packages(self.location)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pkg_resources/__init__.py", line 2187, in fixup_namespace_packages
#     subpath = _handle_ns(package, path_item)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pkg_resources/__init__.py", line 2096, in _handle_ns
#     loader = importer.find_module(packageName)
#   File "<frozen importlib._bootstrap_external>", line 423, in _find_module_shim
#   File "<frozen importlib._bootstrap_external>", line 1223, in find_loader
#   File "<frozen importlib._bootstrap_external>", line 1259, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 60, in _path_join
#   File "<frozen importlib._bootstrap_external>", line 59, in <listcomp>
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/jhj/.local/lib/python3.6/site-packages/IPython/utils/_process_posix.py", line 156, in system
#     child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pexpect/pty_spawn.py", line 197, in __init__
#     self._spawn(command, args, preexec_fn, dimensions)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pexpect/pty_spawn.py", line 297, in _spawn
#     cwd=self.cwd, **kwargs)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pexpect/pty_spawn.py", line 308, in _spawnpty
#     return ptyprocess.PtyProcess.spawn(args, **kwargs)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ptyprocess/ptyprocess.py", line 302, in spawn
#     exec_err_data = os.read(exec_err_pipe_read, 4096)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jhj/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-874465f1e292>", line 27, in <module>
#     get_ipython().system('/home/jhj/anaconda3/envs/CloudDetection/bin/python {cmd}')
#   File "/home/jhj/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2225, in system_piped
#     self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#   File "/home/jhj/.local/lib/python3.6/site-packages/IPython/utils/_process_posix.py", line 172, in system
#     child.sendline(chr(3))
# UnboundLocalError: local variable 'child' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jhj/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'UnboundLocalError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jhj/.local/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/jhj/.local/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/home/jhj/.local/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/inspect.py", line 1480, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/inspect.py", line 1438, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/inspect.py", line 739, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/posixpath.py", line 386, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/posixpath.py", line 419, in _joinrealpath
#     newpath = join(path, name)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/posixpath.py", line 85, in join
#     if b.startswith(sep):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     155             else:
# --> 156                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     157             flush = sys.stdout.flush
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions)
#     196         else:
# --> 197             self._spawn(command, args, preexec_fn, dimensions)
#     198
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pexpect/pty_spawn.py in _spawn(self, command, args, preexec_fn, dimensions)
#     296         self.ptyproc = self._spawnpty(self.args, env=self.env,
# --> 297                                      cwd=self.cwd, **kwargs)
#     298
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/pexpect/pty_spawn.py in _spawnpty(self, args, **kwargs)
#     307         '''Spawn a pty and return an instance of PtyProcess.'''
# --> 308         return ptyprocess.PtyProcess.spawn(args, **kwargs)
#     309
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ptyprocess/ptyprocess.py in spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions)
#     301         os.close(exec_err_pipe_write)
# --> 302         exec_err_data = os.read(exec_err_pipe_read, 4096)
#     303         os.close(exec_err_pipe_read)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2909                 #rprint('Running code', repr(code_obj)) # dbg
# -> 2910                 exec(code_obj, self.user_global_ns, self.user_ns)
#    2911             finally:
#
# <ipython-input-2-874465f1e292> in <module>()
#      26
# ---> 27             get_ipython().system('/home/jhj/anaconda3/envs/CloudDetection/bin/python {cmd}')
#      28
#
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in system_piped(self, cmd)
#    2224         # Instead, we store the exit_code in user_ns.
# -> 2225         self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#    2226
#
# ~/.local/lib/python3.6/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     171             # curses.ascii.ETX).
# --> 172             child.sendline(chr(3))
#     173             # Read and print any more output the program might produce on its
#
# UnboundLocalError: local variable 'child' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1827                         # in the engines. This should return a list of strings.
# -> 1828                         stb = value._render_traceback_()
#    1829                     except Exception:
#
# AttributeError: 'UnboundLocalError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2925             if result is not None:
#    2926                 result.error_in_exec = sys.exc_info()[1]
# -> 2927             self.showtraceback(running_compiled_code=True)
#    2928         else:
#    2929             outflag = False
#
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1829                     except Exception:
#    1830                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 1831                                             value, tb, tb_offset=tb_offset)
#    1832
#    1833                     self._showtraceback(etype, value, stb)
#
# ~/.local/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369         self.tb = tb
#    1370         return FormattedTB.structured_traceback(
# -> 1371             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1372
#    1373
#
# ~/.local/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1277             # Verbose modes need a full traceback
#    1278             return VerboseTB.structured_traceback(
# -> 1279                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1280             )
#    1281         else:
#
# ~/.local/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1138             exception = self.get_parts_of_chained_exception(evalue)
#    1139             if exception:
# -> 1140                 formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
#    1141                 etype, evalue, etb = exception
#    1142             else:
#
# TypeError: must be str, not list
# ERROR:tornado.general:Uncaught exception, closing connection.
# Traceback (most recent call last):
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/jhj/.local/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 421, in execute_request
#     self._abort_queues()
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 637, in _abort_queues
#     self._abort_queue(stream)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 662, in _abort_queue
#     poller.poll(50)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/zmq/sugar/poll.py", line 99, in poll
#     return zmq_poll(self.sockets, timeout=timeout)
#   File "zmq/backend/cython/_poll.pyx", line 116, in zmq.backend.cython._poll.zmq_poll (zmq/backend/cython/_poll.c:2036)
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/_poll.c:2418)
# KeyboardInterrupt
# ERROR:tornado.general:Uncaught exception, closing connection.
# Traceback (most recent call last):
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/jhj/.local/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 421, in execute_request
#     self._abort_queues()
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 637, in _abort_queues
#     self._abort_queue(stream)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 662, in _abort_queue
#     poller.poll(50)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/zmq/sugar/poll.py", line 99, in poll
#     return zmq_poll(self.sockets, timeout=timeout)
#   File "zmq/backend/cython/_poll.pyx", line 116, in zmq.backend.cython._poll.zmq_poll (zmq/backend/cython/_poll.c:2036)
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/_poll.c:2418)
# KeyboardInterrupt

# %%
activation_functions = ['relu', 'swish']
#loss_functions = ['binary_crossentropy', 'jaccard_coef_loss']
L2reg = [0, 1e-2]
#optimizers = ['Adam', 'Nadam']
dropout_vals = [0, 0.5]
epochs = 2
num_gpus = 2

# Train the models
for activation_func in activation_functions:
    for l2 in L2reg:
        #for optimizer in optimizers:
        for dropout in dropout_vals:
            params = get_params('U-net', 'Landsat8')
            params.modelID = datetime.datetime.now().strftime("%y%m%d%H%M%S")
            #params.loss_func = loss_function
            params.L2reg = l2
            params.optimizer = 'Adam'
            params.activation_func = activation_func
            params.dropout = dropout
            params.epochs = epochs
            params.brightness_augmentation = False
            params.batch_size = 16
            params.learning_rate = 1e-2

            print('###########################################')
            print('# activation_func: ' + activation_func)
            #print('# loss_function:   ' + loss_function)
            #print('# optimizer:       ' + optimizer)
            print('###########################################')                
            model = Unet()
            model.train(num_gpus, params)
            del model
            K.clear_session()
            gc.collect()
            model = Unet()
            evaluate_test_set(model, num_gpus, params)
            del model
            K.clear_session()
            gc.collect()
# Out:
# ###########################################
# # activation_func: relu
# ###########################################
# ------------------------------------------
# Always training from scratch at the moment
# ------------------------------------------
# Start training:
# Epoch 1/2
# 40/40 [==============================] - 23s 566ms/step - loss: 0.4867 - binary_crossentropy: 0.4867 - jaccard_coef_loss: 5.5070 - jaccard_coef: 0.4843 - jaccard_coef_thresholded: 0.5703 - acc: 0.7612 - val_loss: 7.6988 - val_binary_crossentropy: 7.6988 - val_jaccard_coef_loss: 9.6049 - val_jaccard_coef: 0.4529 - val_jaccard_coef_thresholded: 0.4563 - val_acc: 0.4570
# Epoch 2/2
# 40/40 [==============================] - 17s 435ms/step - loss: 0.3834 - binary_crossentropy: 0.3834 - jaccard_coef_loss: 4.6212 - jaccard_coef: 0.5451 - jaccard_coef_thresholded: 0.6555 - acc: 0.8191 - val_loss: 5.9072 - val_binary_crossentropy: 5.9072 - val_jaccard_coef_loss: 16.7353 - val_jaccard_coef: 0.0343 - val_jaccard_coef_thresholded: 0.0343 - val_acc: 0.6333
# ------------------------------------------
# Evaluate model on test data set:
# ------------------------------------------
# ../src/models/model_utils.py:148: RuntimeWarning: invalid value encountered in double_scalars
#   pixel_jaccard[j, i] = tp[j, i] / (tp[j, i] + fp[j, i] + fn[j, i])
# Testing product  0 : LC80420082013220LGN00
# Prediction finished in      : 39.52379083633423s
# ------------------------------------------
# Testing product  1 : LC81330312013202LGN00
# Prediction finished in      : 30.22528600692749s
# ------------------------------------------
# Testing product  2 : LC81360302014162LGN00
# Prediction finished in      : 32.125502824783325s
# ------------------------------------------
# Testing product  3 : LC81550082014263LGN00
# Prediction finished in      : 39.77647876739502s
# ------------------------------------------
# Testing product  4 : LC81570452014213LGN00
# Prediction finished in      : 30.89067769050598s
# ------------------------------------------
# Testing product  5 : LC81640502013179LGN01
# Prediction finished in      : 29.99546480178833s
# ------------------------------------------
# Testing product  6 : LC80070662014234LGN00
# Prediction finished in      : 29.990525007247925s
# ------------------------------------------
# Testing product  7 : LC80160502014041LGN00
# Prediction finished in      : 30.01647925376892s
# ------------------------------------------
# Testing product  8 : LC81170272014189LGN00
# Prediction finished in      : 32.829740047454834s
# ------------------------------------------
# Testing product  9 : LC81310182013108LGN01
# Prediction finished in      : 31.050866842269897s
# ------------------------------------------
# Testing product  10 : LC81800662014230LGN00
# Prediction finished in      : 30.346034049987793s
# ------------------------------------------
# Testing product  11 : LC82290572014141LGN00
# Prediction finished in      : 30.21420645713806s
# ------------------------------------------
# Testing product  12 : LC80290372013257LGN00
# Prediction finished in      : 31.290246963500977s
# ------------------------------------------
# Testing product  13 : LC81220312014208LGN00
# Prediction finished in      : 31.24444580078125s
# ------------------------------------------
# Testing product  14 : LC81220422014096LGN00
# Prediction finished in      : 31.25005865097046s
# ------------------------------------------
# Testing product  15 : LC81490432014141LGN00
# Prediction finished in      : 31.271077394485474s
# ------------------------------------------
# Testing product  16 : LC81510262014139LGN00
# Prediction finished in      : 31.282549619674683s
# ------------------------------------------
# Testing product  17 : LC81750512013208LGN00
# Prediction finished in      : 30.335771322250366s
# ------------------------------------------
# Testing product  18 : LC80010732013109LGN00
# Prediction finished in      : 29.531496286392212s
# ------------------------------------------
# Testing product  19 : LC80350192014190LGN00
# Prediction finished in      : 34.29165506362915s
# ------------------------------------------
# Testing product  20 : LC80750172013163LGN00
# Prediction finished in      : 32.66205072402954s
# ------------------------------------------
# Testing product  21 : LC80760182013170LGN00
# Prediction finished in      : 33.198598861694336s
# ------------------------------------------
# Testing product  22 : LC81020802014100LGN00
# Prediction finished in      : 29.98228359222412s
# ------------------------------------------
# Testing product  23 : LC81600462013215LGN00
# Prediction finished in      : 30.640244007110596s
# ------------------------------------------
# Testing product  24 : LC80060102014147LGN00
# Prediction finished in      : 36.53308343887329s
# ------------------------------------------
# Testing product  25 : LC80250022014232LGN00
# Prediction finished in      : 39.268497943878174s
# ------------------------------------------
# Testing product  26 : LC80841202014309LGN00
# Prediction finished in      : 32.829625844955444s
# ------------------------------------------
# Testing product  27 : LC82171112014297LGN00
# Prediction finished in      : 40.38074326515198s
# ------------------------------------------
# Testing product  28 : LC82271192014287LGN00
# Prediction finished in      : 37.76929211616516s
# ------------------------------------------
# Testing product  29 : LC82320072014226LGN00
# Prediction finished in      : 39.42600679397583s
# ------------------------------------------
# Testing product  30 : LC80170312013157LGN00
# Prediction finished in      : 29.038427114486694s
# ------------------------------------------
# Testing product  31 : LC80410372013357LGN00
# Prediction finished in      : 30.961442947387695s
# ------------------------------------------
# Testing product  32 : LC80460282014171LGN00
# Prediction finished in      : 31.319193124771118s
# ------------------------------------------
# Testing product  33 : LC81620432014072LGN00
# Prediction finished in      : 29.813056468963623s
# ------------------------------------------
# Testing product  34 : LC81770262013254LGN00
# Prediction finished in      : 33.72128677368164s
# ------------------------------------------
# Testing product  35 : LC81920192013103LGN01
# Prediction finished in      : 30.70340919494629s
# ------------------------------------------
# Testing product  36 : LC80120552013202LGN00
# Prediction finished in      : 29.827633142471313s
# ------------------------------------------
# Testing product  37 : LC80180082014215LGN00
# Prediction finished in      : 37.709585428237915s
# ------------------------------------------
# Testing product  38 : LC80430122014214LGN00
# Prediction finished in      : 34.83331036567688s
# ------------------------------------------
# Testing product  39 : LC81130632014241LGN00
# Prediction finished in      : 30.12128448486328s
# ------------------------------------------
# Testing product  40 : LC81240462014238LGN00
# Prediction finished in      : 31.269227027893066s
# ------------------------------------------
# Testing product  41 : LC82150712013152LGN00
# Prediction finished in      : 28.972593784332275s
# ------------------------------------------
# Testing product  42 : LC80310202013223LGN00
# Prediction finished in      : 33.525349855422974s
# ------------------------------------------
# Testing product  43 : LC80340192014167LGN00
# Prediction finished in      : 32.673813819885254s
# ------------------------------------------
# Testing product  44 : LC81020152014036LGN00
# Prediction finished in      : 34.09236240386963s
# ------------------------------------------
# Testing product  45 : LC81030162014107LGN00
# Prediction finished in      : 34.44114303588867s
# ------------------------------------------
# Testing product  46 : LC81080162013171LGN00
# Prediction finished in      : 32.69579720497131s
# ------------------------------------------
# Testing product  47 : LC81080182014238LGN00
# Prediction finished in      : 32.96713948249817s
# ###########################################
# # activation_func: relu
# ###########################################
# ------------------------------------------
# Always training from scratch at the moment
# ------------------------------------------
# Start training:
# Epoch 1/2
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     515             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 516             c_api.TF_GetCode(self.status.status))
#     517     # Delete the underlying status object from memory otherwise it stays alive
#
# InternalError: CUB segmented reduce errorinvalid configuration argument
# 	 [[Node: metrics/jaccard_coef_loss/Sum = Sum[T=DT_FLOAT, Tidx=DT_INT32, keep_dims=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"](metrics/jaccard_coef_loss/mul, metrics/jaccard_coef_loss/Sum_1/reduction_indices)]]
# 	 [[Node: training/Adam/gradients/conv2d_19_1/concat_grad/Slice_1/_1617 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:1", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_7305_training/Adam/gradients/conv2d_19_1/concat_grad/Slice_1", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:1"]()]]
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-2-f0657f840d65> in <module>()
#      30             print('###########################################')
#      31             model = Unet()
# ---> 32             model.train(num_gpus, params)
#      33             del model
#      34             K.clear_session()
#
# ~/phd/GitProjects/SentinelSemanticSegmentation/src/models/Unet.py in train(self, num_gpus, params)
#     185                             #callbacks=[model_checkpoint, tensorboard, csv_logger],
#     186                             validation_data=val_generator,
# --> 187                             validation_steps=10)
#     188
#     189         '''
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2222                     outs = self.train_on_batch(x, y,
#    2223                                                sample_weight=sample_weight,
# -> 2224                                                class_weight=class_weight)
#    2225
#    2226                     if not isinstance(outs, list):
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1881             ins = x + y + sample_weights
#    1882         self._make_train_function()
# -> 1883         outputs = self.train_function(ins)
#    1884         if len(outputs) == 1:
#    1885             return outputs[0]
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1372         except KeyError:
#    1373           pass
# -> 1374       raise type(e)(node_def, op, message)
#    1375
#    1376   def _extend_graph(self):
#
# InternalError: CUB segmented reduce errorinvalid configuration argument
# 	 [[Node: metrics/jaccard_coef_loss/Sum = Sum[T=DT_FLOAT, Tidx=DT_INT32, keep_dims=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"](metrics/jaccard_coef_loss/mul, metrics/jaccard_coef_loss/Sum_1/reduction_indices)]]
# 	 [[Node: training/Adam/gradients/conv2d_19_1/concat_grad/Slice_1/_1617 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:1", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_7305_training/Adam/gradients/conv2d_19_1/concat_grad/Slice_1", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:1"]()]]
#
# Caused by op 'metrics/jaccard_coef_loss/Sum', defined at:
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/jhj/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/jhj/.local/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/jhj/.local/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/jhj/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/jhj/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/jhj/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-f0657f840d65>", line 32, in <module>
#     model.train(num_gpus, params)
#   File "../src/models/Unet.py", line 165, in train
#     metrics=['binary_crossentropy', jaccard_coef_loss, jaccard_coef, jaccard_coef_thresholded, 'accuracy'])
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/engine/training.py", line 934, in compile
#     handle_metrics(output_metrics)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/engine/training.py", line 913, in handle_metrics
#     mask=masks[i])
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/engine/training.py", line 429, in weighted
#     score_array = fn(y_true, y_pred)
#   File "../src/models/model_utils.py", line 57, in jaccard_coef_loss
#     return -K.log(jaccard_coef(y_true, y_pred)) + binary_crossentropy(y_pred, y_true)
#   File "../src/models/model_utils.py", line 25, in jaccard_coef
#     intersection = K.sum(y_true * y_pred, axis=[0, -1, -2])  # Sum the product in all axes
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 1265, in sum
#     return tf.reduce_sum(x, axis, keepdims)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 432, in new_func
#     return func(*args, **kwargs)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py", line 1373, in reduce_sum
#     name=name))
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py", line 4864, in _sum
#     name=name)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3271, in create_op
#     op_def=op_def)
#   File "/home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1650, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InternalError (see above for traceback): CUB segmented reduce errorinvalid configuration argument
# 	 [[Node: metrics/jaccard_coef_loss/Sum = Sum[T=DT_FLOAT, Tidx=DT_INT32, keep_dims=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"](metrics/jaccard_coef_loss/mul, metrics/jaccard_coef_loss/Sum_1/reduction_indices)]]
# 	 [[Node: training/Adam/gradients/conv2d_19_1/concat_grad/Slice_1/_1617 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:1", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_7305_training/Adam/gradients/conv2d_19_1/concat_grad/Slice_1", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:1"]()]]

# %%
classes = [['thin', 'cloud']]
epochs = 50
num_gpus = 1

# Train the models
for cls in classes:
        print('###########################################')
        print('# class:   ' + str(cls))
        print('###########################################')
        params = get_params('U-net', 'Landsat8')
        params.batch_size = 12
        params.modelID = datetime.datetime.now().strftime("%y%m%d%H%M%S")
        params.loss_func = 'binary_crossentropy'
        params.optimizer = 'Nadam'
        params.activation_func = 'swish'
        params.epochs = epochs
        params.cls = cls
        
        model = Unet()
        model.train(num_gpus, params)

        # Test different threshold values for the trained model (remember timeID is the same for all thresholds)
        for threshold in thresholds:            
            params.threshold = threshold
            avg_jaccard, product_names, product_jaccard = evaluate_test_set(model, num_gpus, params)
            write_csv_files(avg_jaccard, product_jaccard, product_names, params)

# %% [markdown]
# # Investigate the trained models

# %%
params = get_params('U-net', 'Landsat8')
df = pd.read_csv(params.project_path + 'reports/Unet/param_optimization.csv' )
#df.sort_values('entire_testset', ascending=False).head(40)
#df.loc[df['modelID'] == 180201172308]
df.loc[df['cls'] == 'shadow']

# %% [markdown]
# # Plot predictions from the desired model

# %%
modelID = '180202154744'
num_gpus = 2

K.clear_session()
model = Unet()
params = get_params('U-net', 'Landsat8')
params.add_hparam('modelID', modelID)
params.activation_func = 'swish'
params.cls = ['shadow']
visualize_test_data(model, num_gpus, params)

# %%
# Overlay pictures 
thresholded = True
transparency = 200
thumbnail_res = 512, 512  # Resolution to be showed
area = (1000, 1000, 7000, 7000)  # Area to be cropped in (min_width, min_height, max_width, max_height)
params.threshold = 0.1
model_name = get_model_name(params)

# Plot predictions
files = sorted(os.listdir(params.project_path + 'data/output/'))  # os.listdir loads in arbitrary order, hence use sorted()
files = [f for f in files if ('thresholded_Unet_Landsat8_' + modelID) in f]  # Filter out one ID for each tile
    
for i, f in enumerate(files, start=1):
    rgb, pred_unet, pred_true = get_predicted_thumbnails(f, thresholded, area, transparency, thumbnail_res, params)

    # Plot
    plt.figure(figsize=(35, 35))
    
    plt.subplot(1, 3, 1)
    plt.title('RGB for tile: ' + f[0:21])
    plt.imshow(rgb)
    
    plt.subplot(1, 3, 2)
    plt.title('Unet for tile: ' + f[0:21])
    plt.imshow(pred_unet)
    
    plt.subplot(1, 3, 3)
    plt.title('True for tile: ' + f[0:21])
    plt.imshow(pred_true)

    plt.show()
