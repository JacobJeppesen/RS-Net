# %%
import sys
import os
import datetime
import pandas as pd
import seaborn as sns
from keras import backend as K
from PIL import Image
Image.MAX_IMAGE_PIXELS = 1000000000   
from matplotlib import pyplot as plt

sys.path.insert(0, '../')
# %load_ext autoreload
# %autoreload 2
from src.models.params import get_params
from src.models.model_utils import evaluate_test_set, write_csv_files
from src.models.Unet import Unet
from src.visualization.make_image_files import visualize_test_data, visualize_landsat8_tile
from src.visualization.visualization_utils import get_predicted_thumbnails 
from src.utils import get_model_name

# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# /home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %% [markdown]
# # Define and run the training loops

# %%
activation_functions = ['swish', 'relu']
loss_functions = ['binary_crossentropy', 'jaccard_coef_loss']
optimizers = ['Adam', 'Nadam']
dropout_vals = [0, 0.5]
epochs = 200
num_gpus = 1

# Train the models
for activation_func in activation_functions:
    for loss_function in loss_functions:
        for optimizer in optimizers:
            for dropout in dropout_vals:
                K.clear_session()
                params = get_params('U-net', 'Landsat8')
                params.modelID = datetime.datetime.now().strftime("%y%m%d%H%M%S")
                params.loss_func = loss_function
                params.optimizer = optimizer
                params.activation_func = activation_func
                params.dropout = dropout
                params.epochs = epochs
                params.brightness_augmentation = False
                params.batch_size = 16

                print('###########################################')
                print('# activation_func: ' + activation_func)
                print('# loss_function:   ' + loss_function)
                print('# optimizer:       ' + optimizer)
                print('###########################################')
                model = Unet()
                model.train(num_gpus, params)
                evaluate_test_set(model, num_gpus, params)
# Out:
# ###########################################
# # activation_func: swish
# # loss_function:   binary_crossentropy
# # optimizer:       Adam
# ###########################################
# ------------------------------------------
# Always training from scratch at the moment
# WARNING:tensorflow:From /home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1344: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/jhj/anaconda3/envs/CloudDetection/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1242: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# ------------------------------------------
# Start training:
# Epoch 1/200
# 40/40 [==============================] - 34s 850ms/step - loss: 0.4052 - binary_crossentropy: 0.4052 - jaccard_coef_loss: 4.5133 - jaccard_coef: 0.5576 - jaccard_coef_thresholded: 0.6664 - acc: 0.8230 - val_loss: 7.2964 - val_binary_crossentropy: 7.2964 - val_jaccard_coef_loss: 42.4193 - val_jaccard_coef: 5.4133e-16 - val_jaccard_coef_thresholded: 5.4133e-16 - val_acc: 0.5473
# Epoch 2/200
# 40/40 [==============================] - 29s 731ms/step - loss: 0.3122 - binary_crossentropy: 0.3122 - jaccard_coef_loss: 3.5946 - jaccard_coef: 0.6247 - jaccard_coef_thresholded: 0.7270 - acc: 0.8663 - val_loss: 10.1404 - val_binary_crossentropy: 10.1404 - val_jaccard_coef_loss: 11.3495 - val_jaccard_coef: 0.3639 - val_jaccard_coef_thresholded: 0.3639 - val_acc: 0.3639
# Epoch 3/200
# 40/40 [==============================] - 29s 735ms/step - loss: 0.2677 - binary_crossentropy: 0.2677 - jaccard_coef_loss: 3.0532 - jaccard_coef: 0.6803 - jaccard_coef_thresholded: 0.7687 - acc: 0.8834 - val_loss: 6.6596 - val_binary_crossentropy: 6.6596 - val_jaccard_coef_loss: 9.4012 - val_jaccard_coef: 0.4645 - val_jaccard_coef_thresholded: 0.4642 - val_acc: 0.4644
# Epoch 4/200
# 40/40 [==============================] - 29s 737ms/step - loss: 0.2914 - binary_crossentropy: 0.2914 - jaccard_coef_loss: 3.1028 - jaccard_coef: 0.6791 - jaccard_coef_thresholded: 0.7588 - acc: 0.8742 - val_loss: 2.1253 - val_binary_crossentropy: 2.1253 - val_jaccard_coef_loss: 9.5181 - val_jaccard_coef: 0.4410 - val_jaccard_coef_thresholded: 0.4348 - val_acc: 0.4348
# Epoch 5/200
# 40/40 [==============================] - 30s 738ms/step - loss: 0.2547 - binary_crossentropy: 0.2547 - jaccard_coef_loss: 2.9623 - jaccard_coef: 0.6944 - jaccard_coef_thresholded: 0.7885 - acc: 0.8928 - val_loss: 2.6098 - val_binary_crossentropy: 2.6098 - val_jaccard_coef_loss: 9.9032 - val_jaccard_coef: 0.4331 - val_jaccard_coef_thresholded: 0.4311 - val_acc: 0.4311
# Epoch 6/200
# 40/40 [==============================] - 30s 741ms/step - loss: 0.2690 - binary_crossentropy: 0.2690 - jaccard_coef_loss: 2.9331 - jaccard_coef: 0.6668 - jaccard_coef_thresholded: 0.7565 - acc: 0.8898 - val_loss: 0.9830 - val_binary_crossentropy: 0.9830 - val_jaccard_coef_loss: 5.8429 - val_jaccard_coef: 0.4705 - val_jaccard_coef_thresholded: 0.5506 - val_acc: 0.7210
# Epoch 7/200
# 40/40 [==============================] - 29s 730ms/step - loss: 0.2401 - binary_crossentropy: 0.2401 - jaccard_coef_loss: 2.7931 - jaccard_coef: 0.6909 - jaccard_coef_thresholded: 0.7831 - acc: 0.8990 - val_loss: 1.2046 - val_binary_crossentropy: 1.2046 - val_jaccard_coef_loss: 6.7267 - val_jaccard_coef: 0.4934 - val_jaccard_coef_thresholded: 0.5428 - val_acc: 0.6522
# Epoch 8/200
# 40/40 [==============================] - 30s 740ms/step - loss: 0.2483 - binary_crossentropy: 0.2483 - jaccard_coef_loss: 2.7021 - jaccard_coef: 0.7057 - jaccard_coef_thresholded: 0.7742 - acc: 0.8907 - val_loss: 1.0093 - val_binary_crossentropy: 1.0093 - val_jaccard_coef_loss: 5.8100 - val_jaccard_coef: 0.4792 - val_jaccard_coef_thresholded: 0.5350 - val_acc: 0.7191
# Epoch 9/200
# 40/40 [==============================] - 30s 744ms/step - loss: 0.2583 - binary_crossentropy: 0.2583 - jaccard_coef_loss: 2.7981 - jaccard_coef: 0.7007 - jaccard_coef_thresholded: 0.7722 - acc: 0.8875 - val_loss: 0.8706 - val_binary_crossentropy: 0.8706 - val_jaccard_coef_loss: 6.7639 - val_jaccard_coef: 0.4402 - val_jaccard_coef_thresholded: 0.6425 - val_acc: 0.7956
# Epoch 10/200
# 40/40 [==============================] - 29s 729ms/step - loss: 0.2405 - binary_crossentropy: 0.2405 - jaccard_coef_loss: 2.6570 - jaccard_coef: 0.7172 - jaccard_coef_thresholded: 0.7950 - acc: 0.8988 - val_loss: 1.1831 - val_binary_crossentropy: 1.1831 - val_jaccard_coef_loss: 7.5498 - val_jaccard_coef: 0.4305 - val_jaccard_coef_thresholded: 0.5386 - val_acc: 0.6576
# Epoch 11/200
# 40/40 [==============================] - 29s 737ms/step - loss: 0.2511 - binary_crossentropy: 0.2511 - jaccard_coef_loss: 2.8224 - jaccard_coef: 0.6879 - jaccard_coef_thresholded: 0.7657 - acc: 0.8893 - val_loss: 0.9568 - val_binary_crossentropy: 0.9568 - val_jaccard_coef_loss: 5.8625 - val_jaccard_coef: 0.4094 - val_jaccard_coef_thresholded: 0.4417 - val_acc: 0.7151
# Epoch 12/200
# 40/40 [==============================] - 29s 731ms/step - loss: 0.2385 - binary_crossentropy: 0.2385 - jaccard_coef_loss: 2.7148 - jaccard_coef: 0.7053 - jaccard_coef_thresholded: 0.7882 - acc: 0.8982 - val_loss: 1.1776 - val_binary_crossentropy: 1.1776 - val_jaccard_coef_loss: 6.1686 - val_jaccard_coef: 0.4523 - val_jaccard_coef_thresholded: 0.6017 - val_acc: 0.7909
# Epoch 13/200
# 40/40 [==============================] - 29s 735ms/step - loss: 0.2147 - binary_crossentropy: 0.2147 - jaccard_coef_loss: 2.3923 - jaccard_coef: 0.7483 - jaccard_coef_thresholded: 0.8215 - acc: 0.9097 - val_loss: 0.7845 - val_binary_crossentropy: 0.7845 - val_jaccard_coef_loss: 5.2793 - val_jaccard_coef: 0.5252 - val_jaccard_coef_thresholded: 0.5920 - val_acc: 0.7692
# Epoch 14/200
# 40/40 [==============================] - 29s 735ms/step - loss: 0.2437 - binary_crossentropy: 0.2437 - jaccard_coef_loss: 2.5721 - jaccard_coef: 0.7038 - jaccard_coef_thresholded: 0.7728 - acc: 0.8978 - val_loss: 0.8737 - val_binary_crossentropy: 0.8737 - val_jaccard_coef_loss: 5.8086 - val_jaccard_coef: 0.4326 - val_jaccard_coef_thresholded: 0.5247 - val_acc: 0.7615
# Epoch 15/200
# 40/40 [==============================] - 29s 731ms/step - loss: 0.2220 - binary_crossentropy: 0.2220 - jaccard_coef_loss: 2.5368 - jaccard_coef: 0.7389 - jaccard_coef_thresholded: 0.8236 - acc: 0.9073 - val_loss: 1.0241 - val_binary_crossentropy: 1.0241 - val_jaccard_coef_loss: 5.8179 - val_jaccard_coef: 0.4827 - val_jaccard_coef_thresholded: 0.5920 - val_acc: 0.7616
# Epoch 16/200
# 40/40 [==============================] - 29s 737ms/step - loss: 0.2423 - binary_crossentropy: 0.2423 - jaccard_coef_loss: 2.6410 - jaccard_coef: 0.7063 - jaccard_coef_thresholded: 0.7777 - acc: 0.8948 - val_loss: 0.9878 - val_binary_crossentropy: 0.9878 - val_jaccard_coef_loss: 5.1217 - val_jaccard_coef: 0.4725 - val_jaccard_coef_thresholded: 0.5410 - val_acc: 0.7789
# Epoch 17/200
# 40/40 [==============================] - 30s 740ms/step - loss: 0.2183 - binary_crossentropy: 0.2183 - jaccard_coef_loss: 2.4695 - jaccard_coef: 0.7260 - jaccard_coef_thresholded: 0.8136 - acc: 0.9121 - val_loss: 0.8290 - val_binary_crossentropy: 0.8290 - val_jaccard_coef_loss: 5.7446 - val_jaccard_coef: 0.4626 - val_jaccard_coef_thresholded: 0.5258 - val_acc: 0.7395
# Epoch 18/200
# 40/40 [==============================] - 29s 735ms/step - loss: 0.2052 - binary_crossentropy: 0.2052 - jaccard_coef_loss: 2.2864 - jaccard_coef: 0.7427 - jaccard_coef_thresholded: 0.7999 - acc: 0.9027 - val_loss: 0.9989 - val_binary_crossentropy: 0.9989 - val_jaccard_coef_loss: 6.3427 - val_jaccard_coef: 0.4043 - val_jaccard_coef_thresholded: 0.4734 - val_acc: 0.7095
# Epoch 19/200
# 40/40 [==============================] - 30s 738ms/step - loss: 0.2203 - binary_crossentropy: 0.2203 - jaccard_coef_loss: 2.4035 - jaccard_coef: 0.7472 - jaccard_coef_thresholded: 0.8325 - acc: 0.9168 - val_loss: 1.0044 - val_binary_crossentropy: 1.0044 - val_jaccard_coef_loss: 5.0675 - val_jaccard_coef: 0.5218 - val_jaccard_coef_thresholded: 0.5523 - val_acc: 0.7586
# Epoch 20/200
# 40/40 [==============================] - 29s 735ms/step - loss: 0.2235 - binary_crossentropy: 0.2235 - jaccard_coef_loss: 2.4367 - jaccard_coef: 0.7299 - jaccard_coef_thresholded: 0.8196 - acc: 0.9160 - val_loss: 1.0614 - val_binary_crossentropy: 1.0614 - val_jaccard_coef_loss: 4.9835 - val_jaccard_coef: 0.4632 - val_jaccard_coef_thresholded: 0.5231 - val_acc: 0.7714
# Epoch 21/200
# 40/40 [==============================] - 29s 728ms/step - loss: 0.1926 - binary_crossentropy: 0.1926 - jaccard_coef_loss: 2.1324 - jaccard_coef: 0.7690 - jaccard_coef_thresholded: 0.8339 - acc: 0.9186 - val_loss: 0.8014 - val_binary_crossentropy: 0.8014 - val_jaccard_coef_loss: 4.9175 - val_jaccard_coef: 0.5522 - val_jaccard_coef_thresholded: 0.6027 - val_acc: 0.7710
# Epoch 22/200
# 40/40 [==============================] - 30s 745ms/step - loss: 0.2383 - binary_crossentropy: 0.2383 - jaccard_coef_loss: 2.6548 - jaccard_coef: 0.7019 - jaccard_coef_thresholded: 0.8078 - acc: 0.9105 - val_loss: 0.6963 - val_binary_crossentropy: 0.6963 - val_jaccard_coef_loss: 3.4974 - val_jaccard_coef: 0.6301 - val_jaccard_coef_thresholded: 0.7372 - val_acc: 0.8674
# Epoch 23/200
# 40/40 [==============================] - 29s 728ms/step - loss: 0.2054 - binary_crossentropy: 0.2054 - jaccard_coef_loss: 2.1598 - jaccard_coef: 0.7629 - jaccard_coef_thresholded: 0.8288 - acc: 0.9169 - val_loss: 1.0811 - val_binary_crossentropy: 1.0811 - val_jaccard_coef_loss: 4.2005 - val_jaccard_coef: 0.6120 - val_jaccard_coef_thresholded: 0.6428 - val_acc: 0.7923
# Epoch 24/200
# 40/40 [==============================] - 29s 736ms/step - loss: 0.2159 - binary_crossentropy: 0.2159 - jaccard_coef_loss: 2.3728 - jaccard_coef: 0.7273 - jaccard_coef_thresholded: 0.8001 - acc: 0.9097 - val_loss: 0.6016 - val_binary_crossentropy: 0.6016 - val_jaccard_coef_loss: 2.8029 - val_jaccard_coef: 0.6291 - val_jaccard_coef_thresholded: 0.6827 - val_acc: 0.8783
# Epoch 25/200
# 40/40 [==============================] - 29s 729ms/step - loss: 0.2300 - binary_crossentropy: 0.2300 - jaccard_coef_loss: 2.4343 - jaccard_coef: 0.7357 - jaccard_coef_thresholded: 0.8104 - acc: 0.9070 - val_loss: 0.6342 - val_binary_crossentropy: 0.6342 - val_jaccard_coef_loss: 3.1029 - val_jaccard_coef: 0.6440 - val_jaccard_coef_thresholded: 0.6944 - val_acc: 0.8600
# Epoch 26/200
# 40/40 [==============================] - 30s 738ms/step - loss: 0.2267 - binary_crossentropy: 0.2267 - jaccard_coef_loss: 2.5282 - jaccard_coef: 0.7224 - jaccard_coef_thresholded: 0.8045 - acc: 0.9086 - val_loss: 0.7781 - val_binary_crossentropy: 0.7781 - val_jaccard_coef_loss: 3.6802 - val_jaccard_coef: 0.5819 - val_jaccard_coef_thresholded: 0.6180 - val_acc: 0.8272
# Epoch 27/200
# 40/40 [==============================] - 30s 741ms/step - loss: 0.2224 - binary_crossentropy: 0.2224 - jaccard_coef_loss: 2.4974 - jaccard_coef: 0.7332 - jaccard_coef_thresholded: 0.8173 - acc: 0.9095 - val_loss: 0.5405 - val_binary_crossentropy: 0.5405 - val_jaccard_coef_loss: 2.3109 - val_jaccard_coef: 0.7098 - val_jaccard_coef_thresholded: 0.7798 - val_acc: 0.9097
# Epoch 28/200
# 40/40 [==============================] - 30s 739ms/step - loss: 0.2160 - binary_crossentropy: 0.2160 - jaccard_coef_loss: 2.4014 - jaccard_coef: 0.7326 - jaccard_coef_thresholded: 0.8114 - acc: 0.9093 - val_loss: 0.5073 - val_binary_crossentropy: 0.5073 - val_jaccard_coef_loss: 2.7447 - val_jaccard_coef: 0.6942 - val_jaccard_coef_thresholded: 0.7520 - val_acc: 0.8795
# Epoch 29/200
# 40/40 [==============================] - 29s 728ms/step - loss: 0.2416 - binary_crossentropy: 0.2416 - jaccard_coef_loss: 2.6399 - jaccard_coef: 0.7128 - jaccard_coef_thresholded: 0.7999 - acc: 0.9033 - val_loss: 0.6709 - val_binary_crossentropy: 0.6709 - val_jaccard_coef_loss: 2.8011 - val_jaccard_coef: 0.7062 - val_jaccard_coef_thresholded: 0.7702 - val_acc: 0.8841
# Epoch 30/200
# 40/40 [==============================] - 30s 738ms/step - loss: 0.2062 - binary_crossentropy: 0.2062 - jaccard_coef_loss: 2.3089 - jaccard_coef: 0.7513 - jaccard_coef_thresholded: 0.8395 - acc: 0.9227 - val_loss: 0.8059 - val_binary_crossentropy: 0.8059 - val_jaccard_coef_loss: 3.8517 - val_jaccard_coef: 0.6362 - val_jaccard_coef_thresholded: 0.6548 - val_acc: 0.8010
# Epoch 31/200
# 40/40 [==============================] - 29s 733ms/step - loss: 0.1951 - binary_crossentropy: 0.1951 - jaccard_coef_loss: 2.1185 - jaccard_coef: 0.7503 - jaccard_coef_thresholded: 0.8118 - acc: 0.9182 - val_loss: 0.7201 - val_binary_crossentropy: 0.7201 - val_jaccard_coef_loss: 2.6880 - val_jaccard_coef: 0.7104 - val_jaccard_coef_thresholded: 0.7562 - val_acc: 0.8787
# Epoch 32/200
# 40/40 [==============================] - 29s 733ms/step - loss: 0.2092 - binary_crossentropy: 0.2092 - jaccard_coef_loss: 2.3267 - jaccard_coef: 0.7343 - jaccard_coef_thresholded: 0.8161 - acc: 0.9169 - val_loss: 0.4132 - val_binary_crossentropy: 0.4132 - val_jaccard_coef_loss: 2.3680 - val_jaccard_coef: 0.6855 - val_jaccard_coef_thresholded: 0.7767 - val_acc: 0.9230
# Epoch 33/200
# 40/40 [==============================] - 29s 734ms/step - loss: 0.1997 - binary_crossentropy: 0.1997 - jaccard_coef_loss: 2.2284 - jaccard_coef: 0.7541 - jaccard_coef_thresholded: 0.8320 - acc: 0.9205 - val_loss: 0.5349 - val_binary_crossentropy: 0.5349 - val_jaccard_coef_loss: 2.1903 - val_jaccard_coef: 0.7402 - val_jaccard_coef_thresholded: 0.8082 - val_acc: 0.9169
# Epoch 34/200
# 40/40 [==============================] - 29s 735ms/step - loss: 0.2309 - binary_crossentropy: 0.2309 - jaccard_coef_loss: 2.4413 - jaccard_coef: 0.7231 - jaccard_coef_thresholded: 0.7922 - acc: 0.9035 - val_loss: 0.5852 - val_binary_crossentropy: 0.5852 - val_jaccard_coef_loss: 2.7590 - val_jaccard_coef: 0.6721 - val_jaccard_coef_thresholded: 0.7797 - val_acc: 0.9119
# Epoch 35/200
# 40/40 [==============================] - 29s 735ms/step - loss: 0.1844 - binary_crossentropy: 0.1844 - jaccard_coef_loss: 2.0875 - jaccard_coef: 0.7653 - jaccard_coef_thresholded: 0.8545 - acc: 0.9318 - val_loss: 0.7283 - val_binary_crossentropy: 0.7283 - val_jaccard_coef_loss: 2.5999 - val_jaccard_coef: 0.7138 - val_jaccard_coef_thresholded: 0.7708 - val_acc: 0.8941
# Epoch 36/200
# 40/40 [==============================] - 29s 729ms/step - loss: 0.1917 - binary_crossentropy: 0.1917 - jaccard_coef_loss: 2.2041 - jaccard_coef: 0.7622 - jaccard_coef_thresholded: 0.8492 - acc: 0.9257 - val_loss: 0.5030 - val_binary_crossentropy: 0.5030 - val_jaccard_coef_loss: 2.0026 - val_jaccard_coef: 0.7348 - val_jaccard_coef_thresholded: 0.7940 - val_acc: 0.9219
# Epoch 37/200
# 40/40 [==============================] - 29s 737ms/step - loss: 0.1836 - binary_crossentropy: 0.1836 - jaccard_coef_loss: 1.9888 - jaccard_coef: 0.7666 - jaccard_coef_thresholded: 0.8329 - acc: 0.9251 - val_loss: 0.8210 - val_binary_crossentropy: 0.8210 - val_jaccard_coef_loss: 2.4688 - val_jaccard_coef: 0.7082 - val_jaccard_coef_thresholded: 0.7605 - val_acc: 0.8991
# Epoch 38/200
# 40/40 [==============================] - 29s 732ms/step - loss: 0.2083 - binary_crossentropy: 0.2083 - jaccard_coef_loss: 2.2479 - jaccard_coef: 0.7445 - jaccard_coef_thresholded: 0.8202 - acc: 0.9169 - val_loss: 0.5907 - val_binary_crossentropy: 0.5907 - val_jaccard_coef_loss: 2.3958 - val_jaccard_coef: 0.7288 - val_jaccard_coef_thresholded: 0.8131 - val_acc: 0.9107
# Epoch 39/200
# 40/40 [==============================] - 29s 728ms/step - loss: 0.2094 - binary_crossentropy: 0.2094 - jaccard_coef_loss: 2.2822 - jaccard_coef: 0.7331 - jaccard_coef_thresholded: 0.8209 - acc: 0.9222 - val_loss: 0.6222 - val_binary_crossentropy: 0.6222 - val_jaccard_coef_loss: 2.6135 - val_jaccard_coef: 0.6903 - val_jaccard_coef_thresholded: 0.7446 - val_acc: 0.8859
# Epoch 40/200
# 40/40 [==============================] - 29s 737ms/step - loss: 0.2423 - binary_crossentropy: 0.2423 - jaccard_coef_loss: 2.7335 - jaccard_coef: 0.7017 - jaccard_coef_thresholded: 0.7914 - acc: 0.8993 - val_loss: 2.7016 - val_binary_crossentropy: 2.7016 - val_jaccard_coef_loss: 6.7513 - val_jaccard_coef: 0.3323 - val_jaccard_coef_thresholded: 0.3749 - val_acc: 0.6871
# Epoch 41/200
# 40/40 [==============================] - 30s 738ms/step - loss: 0.2173 - binary_crossentropy: 0.2173 - jaccard_coef_loss: 2.4435 - jaccard_coef: 0.7342 - jaccard_coef_thresholded: 0.8082 - acc: 0.9046 - val_loss: 1.0809 - val_binary_crossentropy: 1.0809 - val_jaccard_coef_loss: 4.4091 - val_jaccard_coef: 0.5844 - val_jaccard_coef_thresholded: 0.6345 - val_acc: 0.7881
# Epoch 42/200
# 40/40 [==============================] - 29s 732ms/step - loss: 0.1990 - binary_crossentropy: 0.1990 - jaccard_coef_loss: 2.2594 - jaccard_coef: 0.7405 - jaccard_coef_thresholded: 0.8216 - acc: 0.9161 - val_loss: 0.7984 - val_binary_crossentropy: 0.7984 - val_jaccard_coef_loss: 3.4416 - val_jaccard_coef: 0.6505 - val_jaccard_coef_thresholded: 0.6870 - val_acc: 0.8275
# Epoch 43/200
# 40/40 [==============================] - 29s 730ms/step - loss: 0.1762 - binary_crossentropy: 0.1762 - jaccard_coef_loss: 1.9153 - jaccard_coef: 0.7768 - jaccard_coef_thresholded: 0.8558 - acc: 0.9343 - val_loss: 0.8289 - val_binary_crossentropy: 0.8289 - val_jaccard_coef_loss: 2.9762 - val_jaccard_coef: 0.6773 - val_jaccard_coef_thresholded: 0.7372 - val_acc: 0.8759
# Epoch 44/200
# 40/40 [==============================] - 30s 739ms/step - loss: 0.2190 - binary_crossentropy: 0.2190 - jaccard_coef_loss: 2.3418 - jaccard_coef: 0.7586 - jaccard_coef_thresholded: 0.8379 - acc: 0.9157 - val_loss: 0.8902 - val_binary_crossentropy: 0.8902 - val_jaccard_coef_loss: 2.8521 - val_jaccard_coef: 0.6911 - val_jaccard_coef_thresholded: 0.7466 - val_acc: 0.8774
# Epoch 45/200
# 40/40 [==============================] - 29s 728ms/step - loss: 0.1862 - binary_crossentropy: 0.1862 - jaccard_coef_loss: 2.0315 - jaccard_coef: 0.7743 - jaccard_coef_thresholded: 0.8435 - acc: 0.9258 - val_loss: 0.6813 - val_binary_crossentropy: 0.6813 - val_jaccard_coef_loss: 2.2447 - val_jaccard_coef: 0.7351 - val_jaccard_coef_thresholded: 0.7697 - val_acc: 0.9030
# Epoch 46/200
# 40/40 [==============================] - 29s 729ms/step - loss: 0.1824 - binary_crossentropy: 0.1824 - jaccard_coef_loss: 1.9510 - jaccard_coef: 0.7846 - jaccard_coef_thresholded: 0.8609 - acc: 0.9352 - val_loss: 0.6588 - val_binary_crossentropy: 0.6588 - val_jaccard_coef_loss: 1.7560 - val_jaccard_coef: 0.7952 - val_jaccard_coef_thresholded: 0.8472 - val_acc: 0.9321
# Epoch 47/200
# 40/40 [==============================] - 29s 730ms/step - loss: 0.1853 - binary_crossentropy: 0.1853 - jaccard_coef_loss: 2.0208 - jaccard_coef: 0.7773 - jaccard_coef_thresholded: 0.8485 - acc: 0.9270 - val_loss: 0.5405 - val_binary_crossentropy: 0.5405 - val_jaccard_coef_loss: 1.9836 - val_jaccard_coef: 0.7548 - val_jaccard_coef_thresholded: 0.8320 - val_acc: 0.9296
# Epoch 48/200
# 40/40 [==============================] - 29s 726ms/step - loss: 0.1737 - binary_crossentropy: 0.1737 - jaccard_coef_loss: 1.9042 - jaccard_coef: 0.7730 - jaccard_coef_thresholded: 0.8428 - acc: 0.9311 - val_loss: 0.6343 - val_binary_crossentropy: 0.6343 - val_jaccard_coef_loss: 1.9796 - val_jaccard_coef: 0.7298 - val_jaccard_coef_thresholded: 0.8009 - val_acc: 0.9252
# Epoch 49/200
# 39/40 [============================>.] - ETA: 0s - loss: 0.1742 - binary_crossentropy: 0.1742 - jaccard_coef_loss: 1.8896 - jaccard_coef: 0.7560 - jaccard_coef_thresholded: 0.8305 - acc: 0.9335
# Epoch 00049: reducing learning rate to 0.0019999999552965165.
# 40/40 [==============================] - 29s 734ms/step - loss: 0.1792 - binary_crossentropy: 0.1792 - jaccard_coef_loss: 1.9216 - jaccard_coef: 0.7553 - jaccard_coef_thresholded: 0.8301 - acc: 0.9320 - val_loss: 0.5331 - val_binary_crossentropy: 0.5331 - val_jaccard_coef_loss: 2.2839 - val_jaccard_coef: 0.7391 - val_jaccard_coef_thresholded: 0.8257 - val_acc: 0.9187
# Epoch 50/200
# 40/40 [==============================] - 29s 734ms/step - loss: 0.1774 - binary_crossentropy: 0.1774 - jaccard_coef_loss: 1.8855 - jaccard_coef: 0.7789 - jaccard_coef_thresholded: 0.8576 - acc: 0.9377 - val_loss: 0.6239 - val_binary_crossentropy: 0.6239 - val_jaccard_coef_loss: 2.0610 - val_jaccard_coef: 0.7530 - val_jaccard_coef_thresholded: 0.8365 - val_acc: 0.9276
# Epoch 51/200
# 40/40 [==============================] - 30s 738ms/step - loss: 0.1580 - binary_crossentropy: 0.1580 - jaccard_coef_loss: 1.8053 - jaccard_coef: 0.7979 - jaccard_coef_thresholded: 0.8632 - acc: 0.9357 - val_loss: 0.7435 - val_binary_crossentropy: 0.7435 - val_jaccard_coef_loss: 2.2563 - val_jaccard_coef: 0.7264 - val_jaccard_coef_thresholded: 0.8033 - val_acc: 0.9170
# Epoch 52/200
# 40/40 [==============================] - 29s 736ms/step - loss: 0.1678 - binary_crossentropy: 0.1678 - jaccard_coef_loss: 1.9311 - jaccard_coef: 0.7680 - jaccard_coef_thresholded: 0.8426 - acc: 0.9315 - val_loss: 0.6579 - val_binary_crossentropy: 0.6579 - val_jaccard_coef_loss: 2.2077 - val_jaccard_coef: 0.7284 - val_jaccard_coef_thresholded: 0.8003 - val_acc: 0.9186
# Epoch 53/200
# 40/40 [==============================] - 29s 731ms/step - loss: 0.1433 - binary_crossentropy: 0.1433 - jaccard_coef_loss: 1.6970 - jaccard_coef: 0.8012 - jaccard_coef_thresholded: 0.8685 - acc: 0.9420 - val_loss: 0.6355 - val_binary_crossentropy: 0.6355 - val_jaccard_coef_loss: 2.1420 - val_jaccard_coef: 0.7386 - val_jaccard_coef_thresholded: 0.8201 - val_acc: 0.9249
# Epoch 54/200
# 40/40 [==============================] - 30s 740ms/step - loss: 0.1380 - binary_crossentropy: 0.1380 - jaccard_coef_loss: 1.5399 - jaccard_coef: 0.8341 - jaccard_coef_thresholded: 0.9034 - acc: 0.9506 - val_loss: 0.5375 - val_binary_crossentropy: 0.5375 - val_jaccard_coef_loss: 1.7495 - val_jaccard_coef: 0.7932 - val_jaccard_coef_thresholded: 0.8692 - val_acc: 0.9433
# Epoch 55/200
# 40/40 [==============================] - 29s 730ms/step - loss: 0.1519 - binary_crossentropy: 0.1519 - jaccard_coef_loss: 1.7655 - jaccard_coef: 0.7954 - jaccard_coef_thresholded: 0.8662 - acc: 0.9390 - val_loss: 0.7425 - val_binary_crossentropy: 0.7425 - val_jaccard_coef_loss: 1.9566 - val_jaccard_coef: 0.7414 - val_jaccard_coef_thresholded: 0.8216 - val_acc: 0.9319
# Epoch 56/200
# 40/40 [==============================] - 29s 728ms/step - loss: 0.1358 - binary_crossentropy: 0.1358 - jaccard_coef_loss: 1.5488 - jaccard_coef: 0.8163 - jaccard_coef_thresholded: 0.8795 - acc: 0.9461 - val_loss: 0.5340 - val_binary_crossentropy: 0.5340 - val_jaccard_coef_loss: 1.8134 - val_jaccard_coef: 0.7694 - val_jaccard_coef_thresholded: 0.8418 - val_acc: 0.9323
# Epoch 57/200
# 40/40 [==============================] - 29s 734ms/step - loss: 0.1543 - binary_crossentropy: 0.1543 - jaccard_coef_loss: 1.6162 - jaccard_coef: 0.8175 - jaccard_coef_thresholded: 0.8695 - acc: 0.9382 - val_loss: 0.6901 - val_binary_crossentropy: 0.6901 - val_jaccard_coef_loss: 2.0926 - val_jaccard_coef: 0.7537 - val_jaccard_coef_thresholded: 0.8302 - val_acc: 0.9276
# Epoch 58/200
# 40/40 [==============================] - 29s 735ms/step - loss: 0.1281 - binary_crossentropy: 0.1281 - jaccard_coef_loss: 1.4898 - jaccard_coef: 0.8195 - jaccard_coef_thresholded: 0.8954 - acc: 0.9543 - val_loss: 0.8182 - val_binary_crossentropy: 0.8182 - val_jaccard_coef_loss: 2.2295 - val_jaccard_coef: 0.7405 - val_jaccard_coef_thresholded: 0.8089 - val_acc: 0.9169
# Epoch 59/200
# 40/40 [==============================] - 29s 737ms/step - loss: 0.1358 - binary_crossentropy: 0.1358 - jaccard_coef_loss: 1.5364 - jaccard_coef: 0.8118 - jaccard_coef_thresholded: 0.8835 - acc: 0.9500 - val_loss: 0.5688 - val_binary_crossentropy: 0.5688 - val_jaccard_coef_loss: 1.7917 - val_jaccard_coef: 0.7708 - val_jaccard_coef_thresholded: 0.8373 - val_acc: 0.9343
# Epoch 60/200
# 40/40 [==============================] - 29s 730ms/step - loss: 0.1624 - binary_crossentropy: 0.1624 - jaccard_coef_loss: 1.8062 - jaccard_coef: 0.7730 - jaccard_coef_thresholded: 0.8434 - acc: 0.9357 - val_loss: 0.5905 - val_binary_crossentropy: 0.5905 - val_jaccard_coef_loss: 2.1134 - val_jaccard_coef: 0.7341 - val_jaccard_coef_thresholded: 0.8030 - val_acc: 0.9226
# Epoch 61/200
# 40/40 [==============================] - 29s 725ms/step - loss: 0.1404 - binary_crossentropy: 0.1404 - jaccard_coef_loss: 1.5528 - jaccard_coef: 0.8229 - jaccard_coef_thresholded: 0.8849 - acc: 0.9461 - val_loss: 0.5593 - val_binary_crossentropy: 0.5593 - val_jaccard_coef_loss: 1.9839 - val_jaccard_coef: 0.7599 - val_jaccard_coef_thresholded: 0.8252 - val_acc: 0.9230
# Epoch 62/200
# 40/40 [==============================] - 29s 725ms/step - loss: 0.1276 - binary_crossentropy: 0.1276 - jaccard_coef_loss: 1.4498 - jaccard_coef: 0.8149 - jaccard_coef_thresholded: 0.8820 - acc: 0.9520 - val_loss: 0.4898 - val_binary_crossentropy: 0.4898 - val_jaccard_coef_loss: 1.4070 - val_jaccard_coef: 0.8443 - val_jaccard_coef_thresholded: 0.8880 - val_acc: 0.9459
# Epoch 63/200
# 12/40 [========>.....................] - ETA: 18s - loss: 0.1487 - binary_crossentropy: 0.1487 - jaccard_coef_loss: 1.6455 - jaccard_coef: 0.7905 - jaccard_coef_thresholded: 0.8382 - acc: 0.9330

# %%
classes = [['thin', 'cloud']]
epochs = 50
num_gpus = 1

# Train the models
for cls in classes:
        print('###########################################')
        print('# class:   ' + str(cls))
        print('###########################################')
        params = get_params('U-net', 'Landsat8')
        params.batch_size = 12
        params.modelID = datetime.datetime.now().strftime("%y%m%d%H%M%S")
        params.loss_func = 'binary_crossentropy'
        params.optimizer = 'Nadam'
        params.activation_func = 'swish'
        params.epochs = epochs
        params.cls = cls
        
        model = Unet()
        model.train(num_gpus, params)

        # Test different threshold values for the trained model (remember timeID is the same for all thresholds)
        for threshold in thresholds:            
            params.threshold = threshold
            avg_jaccard, product_names, product_jaccard = evaluate_test_set(model, num_gpus, params)
            write_csv_files(avg_jaccard, product_jaccard, product_names, params)

# %% [markdown]
# # Investigate the trained models

# %%
params = get_params('U-net', 'Landsat8')
df = pd.read_csv(params.project_path + 'reports/Unet/param_optimization.csv' )
#df.sort_values('entire_testset', ascending=False).head(40)
#df.loc[df['modelID'] == 180201172308]
df.loc[df['cls'] == 'shadow']

# %% [markdown]
# # Plot predictions from the desired model

# %%
modelID = '180202154744'
num_gpus = 2

K.clear_session()
model = Unet()
params = get_params('U-net', 'Landsat8')
params.add_hparam('modelID', modelID)
params.activation_func = 'swish'
params.cls = ['shadow']
visualize_test_data(model, num_gpus, params)

# %%
# Overlay pictures 
thresholded = True
transparency = 200
thumbnail_res = 512, 512  # Resolution to be showed
area = (1000, 1000, 7000, 7000)  # Area to be cropped in (min_width, min_height, max_width, max_height)
params.threshold = 0.1
model_name = get_model_name(params)

# Plot predictions
files = sorted(os.listdir(params.project_path + 'data/output/'))  # os.listdir loads in arbitrary order, hence use sorted()
files = [f for f in files if ('thresholded_Unet_Landsat8_' + modelID) in f]  # Filter out one ID for each tile
    
for i, f in enumerate(files, start=1):
    rgb, pred_unet, pred_true = get_predicted_thumbnails(f, thresholded, area, transparency, thumbnail_res, params)

    # Plot
    plt.figure(figsize=(35, 35))
    
    plt.subplot(1, 3, 1)
    plt.title('RGB for tile: ' + f[0:21])
    plt.imshow(rgb)
    
    plt.subplot(1, 3, 2)
    plt.title('Unet for tile: ' + f[0:21])
    plt.imshow(pred_unet)
    
    plt.subplot(1, 3, 3)
    plt.title('True for tile: ' + f[0:21])
    plt.imshow(pred_true)

    plt.show()
